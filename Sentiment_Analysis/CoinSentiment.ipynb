# %%
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mikev\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
load_dotenv()
api_key = os.getenv("news_api")
print(api_key)
# Out:
# 6328236de8a042eba8425dcef7ff96dc

# %%
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %%
btc_news = newsapi.get_everything(q = "bitcoin", language = "en")
print(f"Total Results: {btc_news['totalResults']}")

eth_news = newsapi.get_everything(q = "ethereum", language = "en")
print(f"Total Results: {eth_news['totalResults']}")

doge_news = newsapi.get_everything(q = "dogecoin", language = "en")
print(f"Total Results: {doge_news['totalResults']}")

car_news = newsapi.get_everything(q = "cardano", language = "en")
print(f"Total Results: {car_news['totalResults']}")

pol_news = newsapi.get_everything(q = "polkadot", language = "en")
print(f"Total Results: {pol_news['totalResults']}")

link_news = newsapi.get_everything(q = "chainlink", language = "en")
print(f"Total Results: {link_news['totalResults']}")
# Out:
# Total Results: 11431
# Total Results: 3273
# Total Results: 1676
# Total Results: 380
# Total Results: 307
# Total Results: 131

# %%
#Bitcoin
btc_sentiments = []

for article in btc_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    

btc_df = pd.DataFrame(btc_sentiments)
btc_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
btc_df = btc_df[btc_cols]
btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.8402       0.0    0.718     0.282
# 1    0.1280       0.0    0.957     0.043
# 2    0.6908       0.0    0.831     0.169
# 3    0.2732       0.0    0.940     0.060
# 4    0.5574       0.0    0.893     0.107
#
#                                                 text
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  It's all about clean energy, it seems. \r\nElo...
# 3  image captionThe move means bitcoin will be ac...
# 4  Several crypto fans that descended on Miami, F...

# %%
#Ethereum
eth_sentiments = []

for article in eth_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    
eth_df = pd.DataFrame(eth_sentiments)
eth_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
eth_df = eth_df[eth_cols]
eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0     0.000     0.000    1.000       0.0
# 1    -0.296     0.061    0.939       0.0
# 2     0.000     0.000    1.000       0.0
# 3    -0.340     0.066    0.934       0.0
# 4     0.000     0.000    1.000       0.0
#
#                                                 text
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  A representation of virtual currency Ethereum ...
# 3  This article was translated from our Spanish e...
# 4  This new mining feature is called 'Norton Cryp...

# %%
#Cardano
car_sentiments = []

for article in car_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        car_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    
car_df = pd.DataFrame(car_sentiments)
car_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
car_df = car_df[car_cols]
car_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.2732     0.000    0.938     0.062
# 2    0.4404     0.000    0.909     0.091
# 3   -0.4215     0.083    0.917     0.000
# 4    0.1027     0.061    0.866     0.073
#
#                                                 text
# 0  A representation of virtual currency Bitcoin i...
# 1  Charles Hoskinson, Cardano Founder as well as ...
# 2  Pavlo Gonchar/SOPA Images/LightRocket via Gett...
# 3  Bitcoin dropped by more than 8% to trade under...
# 4  Opinions expressed by Entrepreneur contributor...

# %%
#DogeCoin
doge_sentiments = []
for article in doge_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        doge_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    
doge_df = pd.DataFrame(doge_sentiments)
doge_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
doge_df = doge_df[doge_cols]
doge_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...

# %%
#Polkadot
pol_sentiments = []
for article in pol_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        pol_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    
pol_df = pd.DataFrame(doge_sentiments)
pol_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
pol_df = pol_df[pol_cols]
pol_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...

# %%
#ChainLink

link_sentiments = []
for article in doge_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        link_sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text      
        })
        
    except AttributeError:
        pass
    
link_df = pd.DataFrame(doge_sentiments)
link_cols = ["Compound", "Negative", "Neutral", "Positive", "text"]
link_df = link_df[link_cols]
link_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...

# %%
btc_df.describe()
# Out:
#         Compound   Negative   Neutral   Positive
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.179920   0.026900   0.89825   0.074800
# std     0.383615   0.039178   0.06832   0.069831
# min    -0.557400   0.000000   0.71800   0.000000
# 25%     0.000000   0.000000   0.84475   0.032250
# 50%     0.165150   0.000000   0.91050   0.065500
# 75%     0.401050   0.059000   0.94375   0.105500
# max     0.840200   0.107000   1.00000   0.282000

# %%
eth_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.110260   0.017850   0.934050   0.048050
# std     0.319522   0.040227   0.071475   0.060335
# min    -0.458800   0.000000   0.782000   0.000000
# 25%     0.000000   0.000000   0.912750   0.000000
# 50%     0.000000   0.000000   0.937000   0.025500
# 75%     0.361200   0.000000   1.000000   0.073000
# max     0.778300   0.151000   1.000000   0.191000

# %%
car_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.318535   0.018850   0.890100   0.091000
# std     0.282968   0.030908   0.056665   0.054378
# min    -0.421500   0.000000   0.766000   0.000000
# 25%     0.159100   0.000000   0.854750   0.062000
# 50%     0.370950   0.000000   0.905500   0.084000
# 75%     0.498075   0.040500   0.933500   0.125500
# max     0.858100   0.083000   1.000000   0.234000

# %%
doge_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.134455   0.028250   0.911850   0.059900
# std     0.433670   0.044798   0.050205   0.063845
# min    -0.659700   0.000000   0.836000   0.000000
# 25%    -0.199825   0.000000   0.871250   0.000000
# 50%     0.234000   0.000000   0.919500   0.059500
# 75%     0.479675   0.049750   0.939250   0.099000
# max     0.648600   0.148000   1.000000   0.164000

# %%
link_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.134455   0.028250   0.911850   0.059900
# std     0.433670   0.044798   0.050205   0.063845
# min    -0.659700   0.000000   0.836000   0.000000
# 25%    -0.199825   0.000000   0.871250   0.000000
# 50%     0.234000   0.000000   0.919500   0.059500
# 75%     0.479675   0.049750   0.939250   0.099000
# max     0.648600   0.148000   1.000000   0.164000

# %%
pol_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.134455   0.028250   0.911850   0.059900
# std     0.433670   0.044798   0.050205   0.063845
# min    -0.659700   0.000000   0.836000   0.000000
# 25%    -0.199825   0.000000   0.871250   0.000000
# 50%     0.234000   0.000000   0.919500   0.059500
# 75%     0.479675   0.049750   0.939250   0.099000
# max     0.648600   0.148000   1.000000   0.164000

# %%
#Tokenizing
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

from collections import Counter
from nltk import ngrams

# %%
wnl = WordNetLemmatizer()
stop = stopwords.words('english')
stop.append("u")
stop.append("it'")
stop.append("'s")
stop.append("n't")
stop.append("_")
stop.append("\`")
stop.append("``")
stop.append("''''")
stop = set(stop)

# %%
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    # Remove the stop words
    words = list(filter(lambda t: t.lower() not in stop, words))
    # Lemmatize Words into root words
    tokens = [wnl.lemmatize(word) for word in words]
    
    return tokens

# %%
btc_df['tokens'] = btc_df['text'].apply(tokenizer)
btc_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.8402       0.0    0.718     0.282
# 1    0.1280       0.0    0.957     0.043
# 2    0.6908       0.0    0.831     0.169
# 3    0.2732       0.0    0.940     0.060
# 4    0.5574       0.0    0.893     0.107
#
#                                                 text  \
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  It's all about clean energy, it seems. \r\nElo...
# 3  image captionThe move means bitcoin will be ac...
# 4  Several crypto fans that descended on Miami, F...
#
#                                               tokens
# 0  [El, Salvador, President, Nayib, Bukele, made,...
# 1  [El, Salvador, become, first, country, world, ...
# 2  [clean, energy, seems, Elon, Musk, Tesla, caus...
# 3  [image, captionThe, move, mean, bitcoin, accep...
# 4  [Several, crypto, fan, descended, Miami, Flori...

# %%
eth_df['tokens'] = eth_df['text'].apply(tokenizer)
eth_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0     0.000     0.000    1.000       0.0
# 1    -0.296     0.061    0.939       0.0
# 2     0.000     0.000    1.000       0.0
# 3    -0.340     0.066    0.934       0.0
# 4     0.000     0.000    1.000       0.0
#
#                                                 text  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  A representation of virtual currency Ethereum ...
# 3  This article was translated from our Spanish e...
# 4  This new mining feature is called 'Norton Cryp...
#
#                                               tokens
# 0  [TL, DR, Cryptocurrency, Ethereum, Solidity, B...
# 1  [long, ago, average, person, clue, NFT, Nowada...
# 2  [representation, virtual, currency, Ethereum, ...
# 3  [article, translated, Spanish, edition, using,...
# 4  [new, mining, feature, called, 'Norton, Crypto...

# %%
car_df['tokens'] = car_df['text'].apply(tokenizer)
car_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.2732     0.000    0.938     0.062
# 2    0.4404     0.000    0.909     0.091
# 3   -0.4215     0.083    0.917     0.000
# 4    0.1027     0.061    0.866     0.073
#
#                                                 text  \
# 0  A representation of virtual currency Bitcoin i...
# 1  Charles Hoskinson, Cardano Founder as well as ...
# 2  Pavlo Gonchar/SOPA Images/LightRocket via Gett...
# 3  Bitcoin dropped by more than 8% to trade under...
# 4  Opinions expressed by Entrepreneur contributor...
#
#                                               tokens
# 0  [representation, virtual, currency, Bitcoin, s...
# 1  [Charles, Hoskinson, Cardano, Founder, well, E...
# 2  [Pavlo, Gonchar/SOPA, Images/LightRocket, via,...
# 3  [Bitcoin, dropped, 8, trade, 36,000, Friday, s...
# 4  [Opinions, expressed, Entrepreneur, contributo...

# %%
doge_df['tokens'] = doge_df['text'].apply(tokenizer)
doge_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text  \
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...
#
#                                               tokens
# 0  [Illustration, Maria, Chimishkyan, lot, way, t...
# 1  [story, originally, appeared, Business, Inside...
# 2  [Opinions, expressed, Entrepreneur, contributo...
# 3  [Opinions, expressed, Entrepreneur, contributo...
# 4  [Dogecoin, meme-based, cryptocurrency, popular...

# %%
link_df['tokens'] = link_df['text'].apply(tokenizer)
link_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text  \
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...
#
#                                               tokens
# 0  [Illustration, Maria, Chimishkyan, lot, way, t...
# 1  [story, originally, appeared, Business, Inside...
# 2  [Opinions, expressed, Entrepreneur, contributo...
# 3  [Opinions, expressed, Entrepreneur, contributo...
# 4  [Dogecoin, meme-based, cryptocurrency, popular...

# %%
pol_df['tokens'] = pol_df['text'].apply(tokenizer)
pol_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.6597     0.148    0.852     0.000
# 1    0.6486     0.000    0.854     0.146
# 2    0.3818     0.000    0.918     0.082
# 3    0.1280     0.000    0.949     0.051
# 4    0.6486     0.000    0.836     0.164
#
#                                                 text  \
# 0  Illustration by Maria Chimishkyan\r\n\n \n\n T...
# 1  This story originally appeared on Business Ins...
# 2  Opinions expressed by Entrepreneur contributor...
# 3  Opinions expressed by Entrepreneur contributor...
# 4  Dogecoin, a meme-based cryptocurrency popular ...
#
#                                               tokens
# 0  [Illustration, Maria, Chimishkyan, lot, way, t...
# 1  [story, originally, appeared, Business, Inside...
# 2  [Opinions, expressed, Entrepreneur, contributo...
# 3  [Opinions, expressed, Entrepreneur, contributo...
# 4  [Dogecoin, meme-based, cryptocurrency, popular...

# %%
btc_words = tokenizer(''.join(str(btc_df['text'].tolist())))
btc_counts = Counter(ngrams(btc_words, n=2))
print(dict(btc_counts))
# Out:
# {('El', 'Salvador'): 5, ('Salvador', 'President'): 1, ('President', 'Nayib'): 2, ('Nayib', 'Bukele'): 2, ('Bukele', 'made'): 1, ('made', 'good'): 1, ('good', 'promise'): 1, ('promise', 'adopt'): 1, ('adopt', 'Bitcoin'): 1, ('Bitcoin', 'legal'): 1, ('legal', 'tender'): 5, ('tender', 'Officials'): 1, ('Officials', 'Central'): 1, ('Central', 'American'): 3, ('American', 'country'): 1, ('country', 'congress'): 1, ('congress', 'voted'): 1, ('voted', 'accept'): 1, ('accept', 'cryptocurrency'): 1, ('cryptocurrency', 'majori…'): 1, ('majori…', '+1414'): 1, ('+1414', 'char'): 1, ('char', "''"): 5, ("''", "'El"): 1, ("'El", 'Salvador'): 1, ('Salvador', 'become'): 2, ('become', 'first'): 2, ('first', 'country'): 2, ('country', 'world'): 2, ('world', 'recognize'): 1, ('recognize', 'cryptocurrency'): 1, ('cryptocurrency', 'bitcoin'): 1, ('bitcoin', 'legal'): 5, ('legal', 'currency'): 1, ('currency', 'according'): 1, ('according', 'President'): 1, ('Bukele', 'tweet'): 1, ('tweet', 'Wednesday'): 1, ('Wednesday', 'Citizens'): 1, ('Citizens', 'able'): 1, ('able', '…'): 1, ('…', '+3840'): 1, ('+3840', 'char'): 1, ('char', 'clean'): 1, ('clean', 'energy'): 1, ('energy', 'seems.\\xa0\\r\\nElon'): 1, ('seems.\\xa0\\r\\nElon', 'Musk'): 1, ('Musk', 'Tesla'): 1, ('Tesla', 'caused'): 1, ('caused', 'ripple'): 1, ('ripple', 'cryptocurrency'): 1, ('cryptocurrency', 'market'): 1, ('market', 'past'): 1, ('past', 'month'): 1, ('month', 'first'): 1, ('first', 'announcing'): 1, ('announcing', 'Tesla'): 1, ('Tesla', 'bought'): 1, ('bought', '1.5'): 1, ('1.5', 'billion'): 1, ('billion', 'worth'): 1, ('worth', 'bitcoi…'): 1, ('bitcoi…', '+2508'): 1, ('+2508', 'char'): 1, ("''", "'image"): 1, ("'image", 'captionThe'): 1, ('captionThe', 'move'): 1, ('move', 'mean'): 1, ('mean', 'bitcoin'): 1, ('bitcoin', 'accepted'): 1, ('accepted', 'everywhere'): 1, ('everywhere', 'good'): 1, ('good', 'service'): 1, ('service', 'alongside'): 1, ('alongside', 'US'): 1, ('US', 'dollar\\r\\nEl'): 1, ('dollar\\r\\nEl', 'Salvador'): 1, ('world', 'officially'): 1, ('officially', 'classify'): 1, ('classify', 'Bitcoin'): 1, ('Bitcoin', 'a…'): 1, ('a…', '+2233'): 1, ('+2233', 'char'): 1, ('char', "'Several"): 1, ("'Several", 'crypto'): 1, ('crypto', 'fan'): 1, ('fan', 'descended'): 1, ('descended', 'Miami'): 1, ('Miami', 'Florida'): 1, ('Florida', 'last'): 1, ('last', 'weekend'): 1, ('weekend', 'largest'): 1, ('largest', 'bitcoin'): 1, ('bitcoin', 'conference'): 1, ('conference', 'history'): 1, ('history', 'saying'): 1, ('saying', 'theyve'): 1, ('theyve', 'tested'): 1, ('tested', 'positive'): 1, ('positive', 'covid-19'): 1, ('covid-19', '\\r\\nLarry'): 1, ('\\r\\nLarry', 'Cermak'): 1, ('Cermak', 'research'): 1, ('research', 'director'): 1, ('director', '…'): 1, ('…', '+2389'): 1, ('+2389', 'char'): 1, ('char', "'Hello"): 2, ("'Hello", 'friend'): 1, ('friend', 'welcome'): 1, ('welcome', 'back'): 2, ('back', 'Week'): 1, ('Week', 'Review'): 1, ('Review', '\\r\\nLast'): 1, ('\\r\\nLast', 'week'): 1, ('week', 'wrote'): 1, ('wrote', 'tech'): 1, ('tech', 'taking'): 1, ('taking', 'Disney'): 1, ('Disney', 'week'): 1, ('week', '’'): 1, ('’', 'talking'): 1, ('talking', 'search'): 1, ('search', 'new'): 1, ('new', 'crypto'): 1, ('crypto', 'messiah.\\r\\nIf'): 1, ('messiah.\\r\\nIf', 'youre'): 1, ('youre', 'reading'): 1, ('reading', 'Tec…'): 1, ('Tec…', '+7741'): 1, ('+7741', 'char'): 1, ('char', "'In"): 1, ("'In", 'spite'): 1, ('spite', 'environmental'): 1, ('environmental', 'regulatory'): 1, ('regulatory', 'ill'): 1, ('ill', 'generally'): 1, ('generally', 'come'): 1, ('come', 'crypto'): 1, ('crypto', 'currency'): 1, ('currency', 'PayPals'): 1, ('PayPals', 'bitcoin'): 1, ('bitcoin', 'ambition'): 1, ('ambition', 'keep'): 1, ('keep', 'ramping'): 1, ('ramping', 'Wednesday'): 1, ('Wednesday', 'Jose'): 1, ('Jose', 'Fernandez'): 1, ('Fernandez', 'da'): 1, ('da', 'Pontethe'): 1, ('Pontethe', 'company'): 1, ('company', 'VP'): 1, ('VP', '…'): 1, ('…', '+2193'): 1, ('+2193', 'char'): 1, ('char', "'By"): 2, ("'B ...

# %%
eth_words = tokenizer(''.join(str(eth_df['text'].tolist())))
eth_counts = Counter(ngrams(eth_words, n=2))
print(dict(eth_counts))
# Out:
# {("'TL", 'DR'): 1, ('DR', 'Cryptocurrency'): 1, ('Cryptocurrency', 'Ethereum'): 1, ('Ethereum', 'Solidity'): 1, ('Solidity', 'Blockchain'): 1, ('Blockchain', 'Developer'): 1, ('Developer', 'Bundle'): 1, ('Bundle', 'sale'): 1, ('sale', '£21.25'): 1, ('£21.25', 'June'): 1, ('June', '17'): 1, ('17', 'saving'): 1, ('saving', '97'): 1, ('97', 'list'): 1, ('list', 'price.\\r\\nIs'): 1, ('price.\\r\\nIs', 'everyone'): 1, ('everyone', 'know'): 1, ('know', 'investing'): 1, ('investing', 'cryptocurrency'): 1, ('cryptocurrency', '…'): 1, ('…', '+949'): 1, ('+949', 'char'): 1, ('char', 'long'): 1, ('long', 'ago'): 1, ('ago', 'average'): 1, ('average', 'person'): 1, ('person', 'clue'): 1, ('clue', 'NFT'): 1, ('NFT', 'Nowadays'): 1, ('Nowadays', "'re"): 1, ("'re", 'making'): 1, ('making', 'headline'): 1, ('headline', 'selling'): 1, ('selling', 'hundred'): 1, ('hundred', 'thousand'): 1, ('thousand', 'buck'): 1, ('buck', 'Predictably'): 1, ('Predictably', 'folk'): 1, ('folk', 'learning'): 1, ('learning', 'NFTs'): 1, ('NFTs', '…'): 1, ('…', '+3056'): 1, ('+3056', 'char'): 1, ('char', "''"): 7, ("''", 'representation'): 1, ('representation', 'virtual'): 1, ('virtual', 'currency'): 1, ('currency', 'Ethereum'): 1, ('Ethereum', 'seen'): 1, ('seen', 'front'): 1, ('front', 'stock'): 1, ('stock', 'graph'): 1, ('graph', 'illustration'): 1, ('illustration', 'taken'): 1, ('taken', 'February'): 1, ('February', '19'): 1, ('19', '2021'): 1, ('2021', 'REUTERS/Dado'): 1, ('REUTERS/Dado', 'Ruvic/Illustration/File'): 1, ('Ruvic/Illustration/File', 'PhotoCryptocurrency'): 1, ('PhotoCryptocurrency', 'Ethereum'): 1, ('Ethereum', 'extende…'): 1, ('extende…', '+1099'): 1, ('+1099', 'char'): 1, ('char', "'This"): 1, ("'This", 'article'): 1, ('article', 'translated'): 1, ('translated', 'Spanish'): 1, ('Spanish', 'edition'): 1, ('edition', 'using'): 1, ('using', 'AI'): 1, ('AI', 'technology'): 1, ('technology', 'Errors'): 1, ('Errors', 'may'): 1, ('may', 'exist'): 1, ('exist', 'due'): 1, ('due', 'process.\\r\\nLast'): 1, ('process.\\r\\nLast', 'May'): 1, ('May', 'VitaliK'): 1, ('VitaliK', 'Buterin'): 1, ('Buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', '27'): 1, ('27', 'ye…'): 1, ('ye…', '+2422'): 1, ('+2422', 'char'): 1, ('char', 'new'): 1, ('new', 'mining'): 1, ('mining', 'feature'): 1, ('feature', 'called'): 1, ('called', "'Norton"): 1, ("'Norton", 'Crypto'): 1, ('Crypto', 'rolling'): 1, ('rolling', 'tomorrow'): 1, ('tomorrow', 'Norton'): 1, ('Norton', '360'): 1, ('360', 'user'): 1, ('user', 'enrolled'): 1, ('enrolled', 'Norton'): 1, ('Norton', 'early'): 1, ('early', 'adopter'): 1, ('adopter', 'program'): 1, ('program', 'Norton'): 1, ('Norton', 'Crypto'): 1, ('Crypto', 'enabled'): 1, ('enabled', 'software'): 1, ('software', 'use…'): 1, ('use…', '+631'): 1, ('+631', 'char'): 1, ("''", "''"): 1, ("''", 'building'): 1, ('building', 'team'): 1, ('team', "''"): 1, ("''", 'page'): 1, ('page', 'declares'): 1, ('declares', 'stating'): 1, ('stating', 'welcome'): 1, ('welcome', 'exceptional'): 1, ('exceptional', 'engineer'): 1, ('engineer', 'solidity'): 1, ('solidity', 'react'): 1, ('react', 'python'): 1, ('python', 'designer'): 1, ('designer', 'gamers'): 1, ('gamers', 'marketer'): 1, ('marketer', 'community'): 1, ('community', 'leader'): 1, ('leader', 'want'): 1, ('want', 'join'): 1, ('join', 'team'): 1, ('team', 'se…'): 1, ('se…', '+478'): 1, ('+478', 'char'): 1, ('char', "'Opinions"): 1, ("'Opinions", 'expressed'): 1, ('expressed', 'Entrepreneur'): 1, ('Entrepreneur', 'contributor'): 1, ('contributor', 'own.\\r\\nLaunched'): 1, ('own.\\r\\nLaunched', 'March'): 1, ('March', '2021'): 1, ('2021', 'racked'): 1, ('racked', 'one'): 1, ('one', 'million'): 1, ('million', 'user'): 1, ('user', 'already'): 1, ('already', 'SafeMoon'): 1, ('SafeMoon', 'blockchain-based'): 1, ('blockchain-based', 'cryptocurrency\\xa0similar'): 1, ('cryptocurrency\\xa0similar', '…'): 1, ('…', '+3939'): 1, ('+3939', 'char'): 1, ('c ...

# %%
car_words = tokenizer(''.join(str(car_df['text'].tolist())))
car_counts = Counter(ngrams(car_words, n=2))
print(dict(car_counts))
# Out:
# {('representation', 'virtual'): 1, ('virtual', 'currency'): 1, ('currency', 'Bitcoin'): 1, ('Bitcoin', 'seen'): 1, ('seen', 'front'): 1, ('front', 'stock'): 1, ('stock', 'graph'): 1, ('graph', 'illustration'): 1, ('illustration', 'taken'): 1, ('taken', 'January'): 1, ('January', '8'): 1, ('8', '2021'): 1, ('2021', 'REUTERS/Dado'): 1, ('REUTERS/Dado', 'Ruvic/File'): 1, ('Ruvic/File', 'Photo/File'): 1, ('Photo/File', 'PhotoCryptocurrencies'): 1, ('PhotoCryptocurrencies', 'posted'): 1, ('posted', 'inflow'): 1, ('inflow', 'last…'): 1, ('last…', '+1506'): 1, ('+1506', 'char'): 1, ('char', "'Charles"): 1, ("'Charles", 'Hoskinson'): 1, ('Hoskinson', 'Cardano'): 1, ('Cardano', 'Founder'): 1, ('Founder', 'well'): 1, ('well', 'Ethereum'): 1, ('Ethereum', 'Co-Founder'): 1, ('Co-Founder', 'sat'): 1, ('sat', 'Yahoo'): 1, ('Yahoo', 'Finances'): 1, ('Finances', 'Akiko'): 1, ('Akiko', 'Fujita'): 1, ('Fujita', 'Zack'): 1, ('Zack', 'Guzman'): 1, ('Guzman', 'talk'): 1, ('talk', 'thing'): 1, ('thing', 'cryptocurrency'): 1, ('cryptocurrency', 'Elon'): 1, ('Elon', 'Musks'): 1, ('Musks', 'recent'): 1, ('recent', 'tweet'): 1, ('tweet', '…'): 1, ('…', '+101'): 1, ('+101', 'char'): 1, ('char', 'Pavlo'): 1, ('Pavlo', 'Gonchar/SOPA'): 1, ('Gonchar/SOPA', 'Images/LightRocket'): 1, ('Images/LightRocket', 'via'): 1, ('via', 'Getty'): 2, ('Getty', 'Images/'): 1, ('Images/', 'Hannibal'): 1, ('Hannibal', 'Hanschke'): 1, ('Hanschke', 'Pool\\r\\nBillionaire'): 1, ('Pool\\r\\nBillionaire', 'Elon'): 1, ('Elon', 'Musk'): 2, ('Musk', 'Monday'): 1, ('Monday', 'posted'): 1, ('posted', 'call'): 1, ('call', 'developer'): 1, ('developer', 'submit'): 1, ('submit', 'idea'): 1, ('idea', 'via'): 1, ('via', 'GitHub'): 1, ('GitHub', 'Reddit'): 1, ('Reddit', 'improve'): 1, ('improve', "dogecoin's…"): 1, ("dogecoin's…", '+1913'): 1, ('+1913', 'char'): 1, ('char', "''"): 4, ("''", 'Bitcoin'): 1, ('Bitcoin', 'dropped'): 1, ('dropped', '8'): 1, ('8', 'trade'): 1, ('trade', '36,000'): 1, ('36,000', 'Friday'): 1, ('Friday', 'session'): 1, ('session', 'slumping'): 1, ('slumping', 'alongside'): 1, ('alongside', 'cryptocurrencies'): 1, ('cryptocurrencies', 'market'): 1, ('market', 'start'): 1, ('start', 'wrapping'): 1, ('wrapping', 'month'): 1, ('month', 'rocked'): 1, ('rocked', 'regulatory'): 1, ('regulatory', 'threat'): 1, ('threat', 'Tes…'): 1, ('Tes…', '+1973'): 1, ('+1973', 'char'): 1, ("''", "'Opinions"): 1, ("'Opinions", 'expressed'): 3, ('expressed', 'Entrepreneur'): 3, ('Entrepreneur', 'contributor'): 3, ('contributor', 'own.\\r\\nOn'): 1, ('own.\\r\\nOn', 'May'): 1, ('May', '12'): 1, ('12', '2021'): 1, ('2021', 'Elon'): 1, ('Musk', 'announced'): 1, ('announced', 'Tesla'): 1, ('Tesla', 'would'): 1, ('would', 'longer'): 1, ('longer', 'accept'): 1, ('accept', 'Bitcoin'): 1, ('Bitcoin', 'form'): 1, ('form', 'payment'): 1, ('payment', 'of\\xa0its'): 1, ('of\\xa0its', 'environmental'): 1, ('environmental', 'impact…'): 1, ('impact…', '+5077'): 1, ('+5077', 'char'): 1, ('char', "'Marnie"): 1, ("'Marnie", 'Griffiths/Getty\\r\\nThe'): 1, ('Griffiths/Getty\\r\\nThe', 'mysterious'): 1, ('mysterious', 'dogecoin'): 1, ('dogecoin', 'whale'): 1, ('whale', 'owns'): 1, ('owns', '28'): 1, ('28', 'circulating'): 1, ('circulating', 'supply'): 1, ('supply', 'cryptocurrency'): 1, ('cryptocurrency', 'seen'): 1, ('seen', 'holding'): 1, ('holding', 'value'): 1, ('value', 'decline'): 1, ('decline', '67'): 1, ('67', 'peak'): 1, ('peak', '8.2'): 1, ('8.2', 'billion'): 1, ('billion', '…'): 1, ('…', '+2286'): 1, ('+2286', 'char'): 1, ('char', "'INA"): 1, ("'INA", 'FASSBENDER/AFP'): 1, ('FASSBENDER/AFP', 'via'): 1, ('Getty', 'Images\\r\\nInvestors'): 1, ('Images\\r\\nInvestors', 'pulled'): 1, ('pulled', 'money'): 1, ('money', 'digital'): 1, ('digital', 'asset'): 1, ('asset', 'third'): 1, ('third', 'week'): 1, ('week', 'running'): 1, ('running', 'making'): 1, ('making', 'longest'): 1, ('longest', 'series'): 1, ('series', 'consecutive'): 1, ('consecutive', 'outflow'): 1, ('outflow', 'since'): 1, ('since', 'Feb ...

# %%
pol_words = tokenizer(''.join(str(pol_df['text'].tolist())))
pol_counts = Counter(ngrams(pol_words, n=2))
print(dict(pol_counts))
# Out:
# {("'Illustration", 'Maria'): 1, ('Maria', 'Chimishkyan\\r\\n\\n'): 1, ('Chimishkyan\\r\\n\\n', '\\n\\n'): 1, ('\\n\\n', 'lot'): 1, ('lot', 'way'): 1, ('way', 'thing'): 1, ('thing', 'go'): 1, ('go', 'wrong'): 1, ('wrong', 'online'): 1, ('online', 'Password'): 1, ('Password', 'database'): 1, ('database', 'get'): 1, ('get', 'breached'): 1, ('breached', 'personal'): 1, ('personal', 'data'): 1, ('data', 'get'): 1, ('get', 'leaked'): 1, ('leaked', 'tracker'): 1, ('tracker', 'pop'): 1, ('pop', 'least'): 1, ('least', 'expect'): 1, ('expect', 'them.…'): 1, ('them.…', '+680'): 1, ('+680', 'char'): 1, ('char', "'This"): 3, ("'This", 'story'): 1, ('story', 'originally'): 2, ('originally', 'appeared'): 2, ('appeared', 'Business'): 1, ('Business', 'InsiderCoinbase'): 1, ('InsiderCoinbase', 'said'): 1, ('said', 'Thursday'): 1, ('Thursday', 'plan'): 1, ('plan', 'to\\xa0give'): 1, ('to\\xa0give', 'away'): 1, ('away', '1.2'): 1, ('1.2', 'million'): 1, ('million', 'dogecoin\\xa0to'): 1, ('dogecoin\\xa0to', 'encourage'): 1, ('encourage', 'user'): 1, ('user', 'take'): 1, ('take', 'advantage'): 1, ('advantage', 'newest'): 1, ('newest', 'cryptocurrency'): 1, ('cryptocurrency', 'tradi…'): 1, ('tradi…', '+1221'): 1, ('+1221', 'char'): 1, ('char', "'Opinions"): 2, ("'Opinions", 'expressed'): 3, ('expressed', 'Entrepreneur'): 3, ('Entrepreneur', 'contributor'): 3, ('contributor', 'own.\\r\\nIn'): 2, ('own.\\r\\nIn', 'blog'): 1, ('blog', 'post'): 1, ('post', 'Coinbase'): 1, ('Coinbase', 'say'): 1, ('say', 'has\\xa0'): 1, ('has\\xa0', '“'): 1, ('“', 'immediately'): 1, ('immediately', '”'): 1, ('”', 'started'): 1, ('started', 'accepting'): 1, ('accepting', 'inbound'): 1, ('inbound', 'transfer'): 1, ('transfer', 'Dogecoin'): 1, ('Dogecoin', 'Pro'): 1, ('Pro', 'trading'): 1, ('trading', 'platform'): 1, ('platform', 'Decrypt…'): 1, ('Decrypt…', '+1403'): 1, ('+1403', 'char'): 1, ('contributor', 'own.\\r\\nLaunched'): 1, ('own.\\r\\nLaunched', 'March'): 1, ('March', '2021'): 1, ('2021', 'racked'): 1, ('racked', 'one'): 1, ('one', 'million'): 1, ('million', 'user'): 1, ('user', 'already'): 1, ('already', 'SafeMoon'): 1, ('SafeMoon', 'blockchain-based'): 1, ('blockchain-based', 'cryptocurrency\\xa0similar'): 1, ('cryptocurrency\\xa0similar', '…'): 1, ('…', '+3939'): 1, ('+3939', 'char'): 1, ('char', "'Dogecoin"): 2, ("'Dogecoin", 'meme-based'): 1, ('meme-based', 'cryptocurrency'): 2, ('cryptocurrency', 'popular'): 2, ('popular', 'among'): 2, ('among', 'retail'): 2, ('retail', 'investor'): 2, ('investor', 'surged'): 2, ('surged', 'Wednesday'): 2, ('Wednesday', 'benefiting'): 2, ('benefiting', 'news'): 2, ('news', 'digital'): 2, ('digital', 'asset'): 2, ('asset', 'exchange'): 2, ('exchange', 'Coinbase'): 2, ('Coinbase', 'COIN.O'): 1, ('COIN.O', 'make'): 1, ('make', 'crypto'): 2, ('crypto', 'unit'): 2, ('unit', 'available'): 2, ('available', 'it…'): 2, ('it…', '+1503'): 1, ('+1503', 'char'): 1, ('char', "'Posted"): 1, ("'Posted", '\\r\\nDogecoin'): 1, ('\\r\\nDogecoin', 'meme-based'): 1, ('Coinbase', 'make'): 1, ('it…', '+66'): 1, ('+66', 'char'): 1, ("'This", 'article'): 2, ('article', 'translated'): 3, ('translated', 'Spanish'): 3, ('Spanish', 'edition'): 3, ('edition', 'using'): 3, ('using', 'AI'): 3, ('AI', 'technology'): 3, ('technology', 'Errors'): 3, ('Errors', 'may'): 3, ('may', 'exist'): 3, ('exist', 'due'): 3, ('due', 'process.\\r\\nLast'): 1, ('process.\\r\\nLast', 'May'): 1, ('May', 'VitaliK'): 1, ('VitaliK', 'Buterin'): 1, ('Buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', '27'): 1, ('27', 'ye…'): 1, ('ye…', '+2422'): 1, ('+2422', 'char'): 1, ('char', "'Marnie"): 1, ("'Marnie", 'Griffiths/Getty\\r\\nThe'): 1, ('Griffiths/Getty\\r\\nThe', 'mysterious'): 1, ('mysterious', 'dogecoin'): 1, ('dogecoin', 'whale'): 1, ('whale', 'owns'): 1, ('owns', '28'): 1, ('28', 'circulating'): 1, ('circulating', 'supply'): 1, ('supply', 'cryptocurrency'): 1, ('cryptocurrency', 'seen'): 1, ('seen', 'h ...

# %%
link_words = tokenizer(''.join(str(link_df['text'].tolist())))
link_counts = Counter(ngrams(link_words, n=2))
print(dict(link_counts))
# Out:
# {("'Illustration", 'Maria'): 1, ('Maria', 'Chimishkyan\\r\\n\\n'): 1, ('Chimishkyan\\r\\n\\n', '\\n\\n'): 1, ('\\n\\n', 'lot'): 1, ('lot', 'way'): 1, ('way', 'thing'): 1, ('thing', 'go'): 1, ('go', 'wrong'): 1, ('wrong', 'online'): 1, ('online', 'Password'): 1, ('Password', 'database'): 1, ('database', 'get'): 1, ('get', 'breached'): 1, ('breached', 'personal'): 1, ('personal', 'data'): 1, ('data', 'get'): 1, ('get', 'leaked'): 1, ('leaked', 'tracker'): 1, ('tracker', 'pop'): 1, ('pop', 'least'): 1, ('least', 'expect'): 1, ('expect', 'them.…'): 1, ('them.…', '+680'): 1, ('+680', 'char'): 1, ('char', "'This"): 3, ("'This", 'story'): 1, ('story', 'originally'): 2, ('originally', 'appeared'): 2, ('appeared', 'Business'): 1, ('Business', 'InsiderCoinbase'): 1, ('InsiderCoinbase', 'said'): 1, ('said', 'Thursday'): 1, ('Thursday', 'plan'): 1, ('plan', 'to\\xa0give'): 1, ('to\\xa0give', 'away'): 1, ('away', '1.2'): 1, ('1.2', 'million'): 1, ('million', 'dogecoin\\xa0to'): 1, ('dogecoin\\xa0to', 'encourage'): 1, ('encourage', 'user'): 1, ('user', 'take'): 1, ('take', 'advantage'): 1, ('advantage', 'newest'): 1, ('newest', 'cryptocurrency'): 1, ('cryptocurrency', 'tradi…'): 1, ('tradi…', '+1221'): 1, ('+1221', 'char'): 1, ('char', "'Opinions"): 2, ("'Opinions", 'expressed'): 3, ('expressed', 'Entrepreneur'): 3, ('Entrepreneur', 'contributor'): 3, ('contributor', 'own.\\r\\nIn'): 2, ('own.\\r\\nIn', 'blog'): 1, ('blog', 'post'): 1, ('post', 'Coinbase'): 1, ('Coinbase', 'say'): 1, ('say', 'has\\xa0'): 1, ('has\\xa0', '“'): 1, ('“', 'immediately'): 1, ('immediately', '”'): 1, ('”', 'started'): 1, ('started', 'accepting'): 1, ('accepting', 'inbound'): 1, ('inbound', 'transfer'): 1, ('transfer', 'Dogecoin'): 1, ('Dogecoin', 'Pro'): 1, ('Pro', 'trading'): 1, ('trading', 'platform'): 1, ('platform', 'Decrypt…'): 1, ('Decrypt…', '+1403'): 1, ('+1403', 'char'): 1, ('contributor', 'own.\\r\\nLaunched'): 1, ('own.\\r\\nLaunched', 'March'): 1, ('March', '2021'): 1, ('2021', 'racked'): 1, ('racked', 'one'): 1, ('one', 'million'): 1, ('million', 'user'): 1, ('user', 'already'): 1, ('already', 'SafeMoon'): 1, ('SafeMoon', 'blockchain-based'): 1, ('blockchain-based', 'cryptocurrency\\xa0similar'): 1, ('cryptocurrency\\xa0similar', '…'): 1, ('…', '+3939'): 1, ('+3939', 'char'): 1, ('char', "'Dogecoin"): 2, ("'Dogecoin", 'meme-based'): 1, ('meme-based', 'cryptocurrency'): 2, ('cryptocurrency', 'popular'): 2, ('popular', 'among'): 2, ('among', 'retail'): 2, ('retail', 'investor'): 2, ('investor', 'surged'): 2, ('surged', 'Wednesday'): 2, ('Wednesday', 'benefiting'): 2, ('benefiting', 'news'): 2, ('news', 'digital'): 2, ('digital', 'asset'): 2, ('asset', 'exchange'): 2, ('exchange', 'Coinbase'): 2, ('Coinbase', 'COIN.O'): 1, ('COIN.O', 'make'): 1, ('make', 'crypto'): 2, ('crypto', 'unit'): 2, ('unit', 'available'): 2, ('available', 'it…'): 2, ('it…', '+1503'): 1, ('+1503', 'char'): 1, ('char', "'Posted"): 1, ("'Posted", '\\r\\nDogecoin'): 1, ('\\r\\nDogecoin', 'meme-based'): 1, ('Coinbase', 'make'): 1, ('it…', '+66'): 1, ('+66', 'char'): 1, ("'This", 'article'): 2, ('article', 'translated'): 3, ('translated', 'Spanish'): 3, ('Spanish', 'edition'): 3, ('edition', 'using'): 3, ('using', 'AI'): 3, ('AI', 'technology'): 3, ('technology', 'Errors'): 3, ('Errors', 'may'): 3, ('may', 'exist'): 3, ('exist', 'due'): 3, ('due', 'process.\\r\\nLast'): 1, ('process.\\r\\nLast', 'May'): 1, ('May', 'VitaliK'): 1, ('VitaliK', 'Buterin'): 1, ('Buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', '27'): 1, ('27', 'ye…'): 1, ('ye…', '+2422'): 1, ('+2422', 'char'): 1, ('char', "'Marnie"): 1, ("'Marnie", 'Griffiths/Getty\\r\\nThe'): 1, ('Griffiths/Getty\\r\\nThe', 'mysterious'): 1, ('mysterious', 'dogecoin'): 1, ('dogecoin', 'whale'): 1, ('whale', 'owns'): 1, ('owns', '28'): 1, ('28', 'circulating'): 1, ('circulating', 'supply'): 1, ('supply', 'cryptocurrency'): 1, ('cryptocurrency', 'seen'): 1, ('seen', 'h ...

# %%
doge_words = tokenizer(''.join(str(doge_df['text'].tolist())))
doge_counts = Counter(ngrams(doge_words, n=2))
print(dict(doge_counts))
# Out:
# {("'Illustration", 'Maria'): 1, ('Maria', 'Chimishkyan\\r\\n\\n'): 1, ('Chimishkyan\\r\\n\\n', '\\n\\n'): 1, ('\\n\\n', 'lot'): 1, ('lot', 'way'): 1, ('way', 'thing'): 1, ('thing', 'go'): 1, ('go', 'wrong'): 1, ('wrong', 'online'): 1, ('online', 'Password'): 1, ('Password', 'database'): 1, ('database', 'get'): 1, ('get', 'breached'): 1, ('breached', 'personal'): 1, ('personal', 'data'): 1, ('data', 'get'): 1, ('get', 'leaked'): 1, ('leaked', 'tracker'): 1, ('tracker', 'pop'): 1, ('pop', 'least'): 1, ('least', 'expect'): 1, ('expect', 'them.…'): 1, ('them.…', '+680'): 1, ('+680', 'char'): 1, ('char', "'This"): 3, ("'This", 'story'): 1, ('story', 'originally'): 2, ('originally', 'appeared'): 2, ('appeared', 'Business'): 1, ('Business', 'InsiderCoinbase'): 1, ('InsiderCoinbase', 'said'): 1, ('said', 'Thursday'): 1, ('Thursday', 'plan'): 1, ('plan', 'to\\xa0give'): 1, ('to\\xa0give', 'away'): 1, ('away', '1.2'): 1, ('1.2', 'million'): 1, ('million', 'dogecoin\\xa0to'): 1, ('dogecoin\\xa0to', 'encourage'): 1, ('encourage', 'user'): 1, ('user', 'take'): 1, ('take', 'advantage'): 1, ('advantage', 'newest'): 1, ('newest', 'cryptocurrency'): 1, ('cryptocurrency', 'tradi…'): 1, ('tradi…', '+1221'): 1, ('+1221', 'char'): 1, ('char', "'Opinions"): 2, ("'Opinions", 'expressed'): 3, ('expressed', 'Entrepreneur'): 3, ('Entrepreneur', 'contributor'): 3, ('contributor', 'own.\\r\\nIn'): 2, ('own.\\r\\nIn', 'blog'): 1, ('blog', 'post'): 1, ('post', 'Coinbase'): 1, ('Coinbase', 'say'): 1, ('say', 'has\\xa0'): 1, ('has\\xa0', '“'): 1, ('“', 'immediately'): 1, ('immediately', '”'): 1, ('”', 'started'): 1, ('started', 'accepting'): 1, ('accepting', 'inbound'): 1, ('inbound', 'transfer'): 1, ('transfer', 'Dogecoin'): 1, ('Dogecoin', 'Pro'): 1, ('Pro', 'trading'): 1, ('trading', 'platform'): 1, ('platform', 'Decrypt…'): 1, ('Decrypt…', '+1403'): 1, ('+1403', 'char'): 1, ('contributor', 'own.\\r\\nLaunched'): 1, ('own.\\r\\nLaunched', 'March'): 1, ('March', '2021'): 1, ('2021', 'racked'): 1, ('racked', 'one'): 1, ('one', 'million'): 1, ('million', 'user'): 1, ('user', 'already'): 1, ('already', 'SafeMoon'): 1, ('SafeMoon', 'blockchain-based'): 1, ('blockchain-based', 'cryptocurrency\\xa0similar'): 1, ('cryptocurrency\\xa0similar', '…'): 1, ('…', '+3939'): 1, ('+3939', 'char'): 1, ('char', "'Dogecoin"): 2, ("'Dogecoin", 'meme-based'): 1, ('meme-based', 'cryptocurrency'): 2, ('cryptocurrency', 'popular'): 2, ('popular', 'among'): 2, ('among', 'retail'): 2, ('retail', 'investor'): 2, ('investor', 'surged'): 2, ('surged', 'Wednesday'): 2, ('Wednesday', 'benefiting'): 2, ('benefiting', 'news'): 2, ('news', 'digital'): 2, ('digital', 'asset'): 2, ('asset', 'exchange'): 2, ('exchange', 'Coinbase'): 2, ('Coinbase', 'COIN.O'): 1, ('COIN.O', 'make'): 1, ('make', 'crypto'): 2, ('crypto', 'unit'): 2, ('unit', 'available'): 2, ('available', 'it…'): 2, ('it…', '+1503'): 1, ('+1503', 'char'): 1, ('char', "'Posted"): 1, ("'Posted", '\\r\\nDogecoin'): 1, ('\\r\\nDogecoin', 'meme-based'): 1, ('Coinbase', 'make'): 1, ('it…', '+66'): 1, ('+66', 'char'): 1, ("'This", 'article'): 2, ('article', 'translated'): 3, ('translated', 'Spanish'): 3, ('Spanish', 'edition'): 3, ('edition', 'using'): 3, ('using', 'AI'): 3, ('AI', 'technology'): 3, ('technology', 'Errors'): 3, ('Errors', 'may'): 3, ('may', 'exist'): 3, ('exist', 'due'): 3, ('due', 'process.\\r\\nLast'): 1, ('process.\\r\\nLast', 'May'): 1, ('May', 'VitaliK'): 1, ('VitaliK', 'Buterin'): 1, ('Buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', '27'): 1, ('27', 'ye…'): 1, ('ye…', '+2422'): 1, ('+2422', 'char'): 1, ('char', "'Marnie"): 1, ("'Marnie", 'Griffiths/Getty\\r\\nThe'): 1, ('Griffiths/Getty\\r\\nThe', 'mysterious'): 1, ('mysterious', 'dogecoin'): 1, ('dogecoin', 'whale'): 1, ('whale', 'owns'): 1, ('owns', '28'): 1, ('28', 'circulating'): 1, ('circulating', 'supply'): 1, ('supply', 'cryptocurrency'): 1, ('cryptocurrency', 'seen'): 1, ('seen', 'h ...

# %%
##Word Cloud Images

from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
btc_cloud = " ".join(btc_words)
wc = WordCloud().generate(btc_cloud)
plt.imshow(wc)

# %%
eth_cloud = " ".join(eth_words)
wc = WordCloud().generate(eth_cloud)
plt.imshow(wc)

# %%
car_cloud = " ".join(car_words)
wc = WordCloud().generate(car_cloud)
plt.imshow(wc)

# %%
link_cloud = " ".join(link_words)
wc = WordCloud().generate(link_cloud)
plt.imshow(wc)

# %%
pol_cloud = " ".join(pol_words)
wc = WordCloud().generate(pol_cloud)
plt.imshow(wc)

# %%
doge_cloud = " ".join(doge_words)
wc = WordCloud().generate(doge_cloud)
plt.imshow(wc)
