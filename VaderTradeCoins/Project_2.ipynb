# %%
import ccxt
import os
import pandas as pd
from dotenv import load_dotenv

# %%
# Load environment variables 
load_dotenv()

# Import environment variables
kraken_public_key = os.getenv("+a6ycjNigyqUOgCFm5OsTN9UBNse3Htdvjj/qBe8QlhACvvMgEoPrzlX")
kraken_secret_key = os.getenv("+a6ycjNigyqUOgCFm5OsTN9UBNse3Htdvjj/qBe8QlhACvvMgEoPrzlX")

# Verify that environment variables were loaded
print(f"Kraken key data type: {type(kraken_public_key)}")
print(f"Kraken secren data type: {type(kraken_secret_key)}")
# Out:
# Kraken key data type: <class 'NoneType'>
# Kraken secren data type: <class 'NoneType'>

# %%
Kraken key data type: <class 'str'>
Kraken secren data type: <class 'str'>
# Out:
#   File "<ipython-input-31-688d3e723be7>", line 1
#     Kraken key data type: <class 'str'>
#              ^
# SyntaxError: invalid syntax

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)

# Display sample data
crypto_df
# Out:
#                                                      AAVE/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEAUD
# symbol                                               AAVE/AUD
# base                                                     AAVE
# quote                                                     AUD
# baseId                                                   AAVE
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'AAVEAUD', 'wsname': 'AAVE/AUD', '...
# altname                                               AAVEAUD
# active                                                   True
#
#                                                      AAVE/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEETH
# symbol                                               AAVE/ETH
# base                                                     AAVE
# quote                                                     ETH
# baseId                                                   AAVE
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'AAVEETH', 'wsname': 'AAVE/ETH', '...
# altname                                               AAVEETH
# active                                                   True
#
#                                                      AAVE/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEEUR
# symbol                                               AAVE/EUR
# base                                                     AAVE
# quote                                                     EUR
# baseId                                                   AAVE
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'AAVEEUR', 'wsname': 'AAVE/EUR', '...
# altname                                               AAVEEUR
# active                                                   True
#
#                                                      AAVE/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEGBP
# symbol                                               AAVE/GBP
# base                                                     AAVE
# quote                                                     GBP
# baseId                                                   AAVE
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'AAVEGBP', 'wsname': 'AAVE/GBP', '...
# altname                                               AAVEGBP
# active                                                   True
#
#                                                      AAVE/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEUSD
# symbol                                               AAVE/USD
# base                                                     AAVE
# quote                                                     USD
# baseId                                                   AAVE
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'AAVEUSD', 'wsname': 'AAVE/USD', '...
# altname                                               AAVEUSD
# active                                                   True
#
#                                                      AAVE/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEXBT
# symbol                                               AAVE/BTC
# base                                                     AAVE
# quote                                                     BTC
# baseId                                                   AAVE
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'AAVEXBT', 'wsname': 'AAVE/XBT', '...
# altname                                               AAVEXBT
# active                                                   True
#
#                                                       ADA/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ADAAUD
# symbol                                                ADA/AUD
# base                                                      ADA
# quote                                                     AUD
# baseId                                                    ADA
# quoteId                                                  ZAUD
# darkpool                                                False
# info        {'altname': 'ADAAUD', 'wsname': 'ADA/AUD', 'ac...
# altname                                                ADAAUD
# active                                                   True
#
#                                                       ADA/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 7}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ADAETH
# symbol                                                ADA/ETH
# base                                                      ADA
# quote                                                     ETH
# baseId                                                    ADA
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# altname                                                ADAETH
# active                                                   True
#
#                                                       ADA/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ADAEUR
# symbol                                                ADA/EUR
# base                                                      ADA
# quote                                                     EUR
# baseId                                                    ADA
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# altname                                                ADAEUR
# active                                                   True
#
#                                                       ADA/GBP  ...  \
# percentage                                               True  ...
# tierBased                                                True  ...
# taker                                                  0.0026  ...
# maker                                                  0.0016  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
# precision                           {'amount': 8, 'price': 5}  ...
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...  ...
# id                                                     ADAGBP  ...
# symbol                                                ADA/GBP  ...
# base                                                      ADA  ...
# quote                                                     GBP  ...
# baseId                                                    ADA  ...
# quoteId                                                  ZGBP  ...
# darkpool                                                False  ...
# info        {'altname': 'ADAGBP', 'wsname': 'ADA/GBP', 'ac...  ...
# altname                                                ADAGBP  ...
# active                                                   True  ...
#
#                                                       YFI/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 0}
# limits      {'amount': {'min': 0.00015, 'max': 100000000.0...
# id                                                     YFIUSD
# symbol                                                YFI/USD
# base                                                      YFI
# quote                                                     USD
# baseId                                                    YFI
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'YFIUSD', 'wsname': 'YFI/USD', 'ac...
# altname                                                YFIUSD
# active                                                   True
#
#                                                       YFI/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 0.00015, 'max': 100000000.0...
# id                                                     YFIXBT
# symbol                                                YFI/BTC
# base                                                      YFI
# quote                                                     BTC
# baseId                                                    YFI
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'YFIXBT', 'wsname': 'YFI/XBT', 'ac...
# altname                                                YFIXBT
# active                                                   True
#
#                                                       EUR/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                   ZEURZUSD
# symbol                                                EUR/USD
# base                                                      EUR
# quote                                                     USD
# baseId                                                   ZEUR
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# altname                                                EURUSD
# active                                                   True
#
#                                                       GBP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                   ZGBPZUSD
# symbol                                                GBP/USD
# base                                                      GBP
# quote                                                     USD
# baseId                                                   ZGBP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# altname                                                GBPUSD
# active                                                   True
#
#                                                       ZRX/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXEUR
# symbol                                                ZRX/EUR
# base                                                      ZRX
# quote                                                     EUR
# baseId                                                    ZRX
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ZRXEUR', 'wsname': 'ZRX/EUR', 'ac...
# altname                                                ZRXEUR
# active                                                   True
#
#                                                       ZRX/GBP  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXGBP
# symbol                                                ZRX/GBP
# base                                                      ZRX
# quote                                                     GBP
# baseId                                                    ZRX
# quoteId                                                  ZGBP
# darkpool                                                False
# info        {'altname': 'ZRXGBP', 'wsname': 'ZRX/GBP', 'ac...
# altname                                                ZRXGBP
# active                                                   True
#
#                                                       ZRX/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXUSD
# symbol                                                ZRX/USD
# base                                                      ZRX
# quote                                                     USD
# baseId                                                    ZRX
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ZRXUSD', 'wsname': 'ZRX/USD', 'ac...
# altname                                                ZRXUSD
# active                                                   True
#
#                                                       ZRX/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 5.0, 'max': 100000000.0}, '...
# id                                                     ZRXXBT
# symbol                                                ZRX/BTC
# base                                                      ZRX
# quote                                                     BTC
# baseId                                                    ZRX
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ZRXXBT', 'wsname': 'ZRX/XBT', 'ac...
# altname                                                ZRXXBT
# active                                                   True
#
#                                                       USD/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZCAD
# symbol                                                USD/CAD
# base                                                      USD
# quote                                                     CAD
# baseId                                                   ZUSD
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# altname                                                USDCAD
# active                                                   True
#
#                                                       USD/JPY
# percentage                                               True
# tierBased                                                True
# taker                                                     0.0
# maker                                                     0.0
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZJPY
# symbol                                                USD/JPY
# base                                                      USD
# quote                                                     JPY
# baseId                                                   ZUSD
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# altname                                                USDJPY
# active                                                   True
#
# [17 rows x 364 columns]

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['AAVE/AUD' 'AAVE/ETH' 'AAVE/EUR' 'AAVE/GBP' 'AAVE/USD' 'AAVE/BTC'
#  'ADA/AUD' 'ADA/ETH' 'ADA/EUR' 'ADA/GBP' 'ADA/USD' 'ADA/USDT' 'ADA/BTC'
#  'ALGO/ETH' 'ALGO/EUR' 'ALGO/GBP' 'ALGO/USD' 'ALGO/BTC' 'ANKR/EUR'
#  'ANKR/GBP' 'ANKR/USD' 'ANKR/BTC' 'ANT/ETH' 'ANT/EUR' 'ANT/USD' 'ANT/BTC'
#  'ATOM/AUD' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/GBP' 'ATOM/USD' 'ATOM/BTC'
#  'AUD/JPY' 'AUD/USD' 'BAL/ETH' 'BAL/EUR' 'BAL/USD' 'BAL/BTC' 'BAT/ETH'
#  'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH' 'BCH/EUR' 'BCH/GBP'
#  'BCH/JPY' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'BNT/EUR' 'BNT/GBP' 'BNT/USD'
#  'BNT/BTC' 'COMP/ETH' 'COMP/EUR' 'COMP/USD' 'COMP/BTC' 'CRV/ETH' 'CRV/EUR'
#  'CRV/USD' 'CRV/BTC' 'DAI/EUR' 'DAI/USD' 'DAI/USDT' 'DASH/EUR' 'DASH/USD'
#  'DASH/BTC' 'DOT/AUD' 'DOT/ETH' 'DOT/EUR' 'DOT/GBP' 'DOT/USD' 'DOT/USDT'
#  'DOT/BTC' 'ENJ/EUR' 'ENJ/GBP' 'ENJ/USD' 'ENJ/BTC' 'EOS/ETH' 'EOS/EUR'
#  'EOS/USD' 'EOS/USDT' 'EOS/BTC' 'ETH2.S/ETH' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI'
#  'ETH/USDC' 'ETH/USDT' 'EUR/AUD' 'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY'
#  'EWT/EUR' 'EWT/GBP' 'EWT/USD' 'EWT/BTC' 'FIL/AUD' 'FIL/ETH' 'FIL/EUR'
#  'FIL/GBP' 'FIL/USD' 'FIL/BTC' 'FLOW/ETH' 'FLOW/EUR' 'FLOW/GBP' 'FLOW/USD'
#  'FLOW/BTC' 'GHST/EUR' 'GHST/GBP' 'GHST/USD' 'GHST/BTC' 'GNO/ETH'
#  'GNO/EUR' 'GNO/USD' 'GNO/BTC' 'GRT/AUD' 'GRT/ETH' 'GRT/EUR' 'GRT/GBP'
#  'GRT/USD' 'GRT/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC' 'KAVA/ETH'
#  'KAVA/EUR' 'KAVA/USD' 'KAVA/BTC' 'KEEP/ETH' 'KEEP/EUR' 'KEEP/USD'
#  'KEEP/BTC' 'KNC/ETH' 'KNC/EUR' 'KNC/USD' 'KNC/BTC' 'KSM/AUD' 'KSM/DOT'
#  'KSM/ETH' 'KSM/EUR' 'KSM/GBP' 'KSM/USD' 'KSM/BTC' 'LINK/AUD' 'LINK/ETH'
#  'LINK/EUR' 'LINK/GBP' 'LINK/USD' 'LINK/USDT' 'LINK/BTC' 'LPT/EUR'
#  'LPT/GBP' 'LPT/USD' 'LPT/BTC' 'LSK/ETH' 'LSK/EUR' 'LSK/USD' 'LSK/BTC'
#  'LTC/AUD' 'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'MANA/ETH' 'MANA/EUR' 'MANA/USD'
#  'MANA/BTC' 'MATIC/EUR' 'MATIC/GBP' 'MATIC/USD' 'MATIC/BTC' 'MINA/EUR'
#  'MINA/GBP' 'MINA/USD' 'MINA/BTC' 'MKR/EUR' 'MKR/GBP' 'MKR/USD' 'MKR/BTC'
#  'NANO/ETH' 'NANO/EUR' 'NANO/USD' 'NANO/BTC' 'OCEAN/EUR' 'OCEAN/GBP'
#  'OCEAN/USD' 'OCEAN/BTC' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH'
#  'OXT/EUR' 'OXT/USD' 'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC'
#  'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'RARI/EUR' 'RARI/GBP'
#  'RARI/USD' 'RARI/BTC' 'REN/EUR' 'REN/GBP' 'REN/USD' 'REN/BTC' 'REP/ETH'
#  'REP/EUR' 'REP/USD' 'REP/BTC' 'SAND/EUR' 'SAND/GBP' 'SAND/USD' 'SAND/BTC'
#  'SC/ETH' 'SC/EUR' 'SC/USD' 'SC/BTC' 'SNX/AUD' 'SNX/ETH' 'SNX/EUR'
#  'SNX/GBP' 'SNX/USD' 'SNX/BTC' 'SOL/EUR' 'SOL/GBP' 'SOL/USD' 'SOL/BTC'
#  'SRM/EUR' 'SRM/GBP' 'SRM/USD' 'SRM/BTC' 'STORJ/ETH' 'STORJ/EUR'
#  'STORJ/USD' 'STORJ/BTC' 'SUSHI/EUR' 'SUSHI/GBP' 'SUSHI/USD' 'SUSHI/BTC'
#  'TBTC/ETH' 'TBTC/EUR' 'TBTC/USD' 'TBTC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD'
#  'TRX/BTC' 'UNI/ETH' 'UNI/EUR' 'UNI/USD' 'UNI/BTC' 'USDC/AUD' 'USDC/EUR'
#  'USDC/GBP' 'USD/CHF' 'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD'
#  'USDT/CHF' 'USDT/EUR' 'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH'
#  'WAVES/EUR' 'WAVES/USD' 'WAVES/BTC' 'BTC/AUD' 'BTC/CHF' 'BTC/DAI'
#  'BTC/USDC' 'BTC/USDT' 'DOGE/EUR' 'DOGE/USD' 'DOGE/USDT' 'ETC/ETH'
#  'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC' 'ETHXBT.d' 'ETH/CAD' 'ETHCAD.d'
#  'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d' 'ETH/JPY' 'ETHJPY.d' 'ETH/USD'
#  'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/JPY' 'LTC/USD' 'MLN/ETH' 'MLN/BTC'
#  'MLN/EUR' 'MLN/USD' 'REPV1/ETH' 'REPV1/BTC' 'REPV1/EUR' 'REPV1/USD'
#  'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT' 'XTZ/AUD' 'XTZ/ETH' 'XTZ/EUR'
#  'XTZ/GBP' 'XTZ/USD' 'XTZ/BTC' 'BTC/CAD' 'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d'
#  'BTC/GBP' 'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d' 'BTC/USD' 'XBTUSD.d' 'DOGE/BTC'
#  'XLM/BTC' 'XLM/AUD' 'XLM/EUR' 'XLM/GBP' 'XLM/USD' 'XMR/BTC' 'XMR/EUR'
#  'XMR/USD' 'XRP/BTC' 'XRP/CAD' 'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC'
#  'ZEC/EUR' 'ZEC/USD' 'YFI/AUD' 'YFI/ETH' 'YFI/EUR' 'YFI/GBP' 'YFI/USD'
#  'YFI/BTC' 'EUR/USD' 'GBP/USD' 'ZRX/EUR' 'ZRX/GBP' 'ZRX/USD' 'ZRX/BTC'
#  'USD/CAD' 'USD/JPY']
# 364

# %%
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'signIn': False,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("ETH/USDC", "1d")
#historical_prices = exchange.fetch_ohlcv("ETH/USDC", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp     open     high      low    close       volume
# 0    1578441600000    91.00   141.38    91.00   139.50    26.788105
# 1    1578528000000   140.00   140.00   135.50   137.87    11.482857
# 2    1578614400000   136.25   144.00   135.01   143.14    50.321235
# 3    1578700800000   142.50   146.96   142.21   144.05    42.134522
# 4    1578787200000   142.06   145.56   141.62   145.56   208.657081
# ..             ...      ...      ...      ...      ...          ...
# 530  1624233600000  2244.20  2255.81  1862.43  1891.74  5793.597717
# 531  1624320000000  1891.02  1995.44  1691.80  1876.66  4794.369246
# 532  1624406400000  1874.99  2044.39  1858.25  1972.84   954.215504
# 533  1624492800000  1974.89  2035.53  1886.92  1982.00   432.195323
# 534  1624579200000  1989.49  2009.65  1988.51  2008.29     2.329068
#
# [535 rows x 6 columns]

# %%
historical_prices = exchange.fetch_ohlcv("BTC/USDC", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp      open      high       low     close      volume
# 0    1578441600000   8300.00   8300.00   7870.00   8020.00    0.155489
# 1    1578528000000   8019.99   8020.00   7500.07   7815.64    0.605046
# 2    1578614400000   7782.53   8150.00   7688.86   8150.00    0.481007
# 3    1578700800000   8180.00   8265.60   8052.40   8189.30    0.399643
# 4    1578787200000   7982.52   8152.38   7604.76   7604.76    0.483472
# ..             ...       ...       ...       ...       ...         ...
# 530  1624233600000  35590.03  35720.40  31225.07  31646.21  557.406347
# 531  1624320000000  31591.72  33236.89  28844.00  32502.72  561.987077
# 532  1624406400000  32514.16  34806.80  32441.09  33645.12  213.199229
# 533  1624492800000  33667.48  35257.16  32360.43  34643.84  127.443946
# 534  1624579200000  34678.76  34883.94  34662.44  34863.69    0.108882
#
# [535 rows x 6 columns]

# %%
historical_prices = exchange.fetch_ohlcv("LINK/USD", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1569369600000   1.90000   2.09980   1.69000   1.84791  4.125657e+04
# 1    1569456000000   1.82786   1.85896   1.53188   1.67701  2.895016e+04
# 2    1569542400000   1.67703   1.70165   1.57654   1.69775  1.680588e+04
# 3    1569628800000   1.69422   1.72181   1.65939   1.70000  1.163314e+04
# 4    1569715200000   1.70000   1.84987   1.65849   1.71263  2.531911e+04
# ..             ...       ...       ...       ...       ...           ...
# 635  1624233600000  21.68865  21.88049  17.00300  17.44000  1.053908e+06
# 636  1624320000000  17.39247  18.79194  15.00000  16.83557  1.056536e+06
# 637  1624406400000  16.84369  19.17850  16.56000  18.40201  5.932553e+05
# 638  1624492800000  18.40471  19.51000  17.36651  19.02903  5.258109e+05
# 639  1624579200000  19.03475  19.35889  19.03475  19.33797  7.019963e+03
#
# [640 rows x 6 columns]

# %%
historical_prices = exchange.fetch_ohlcv("DOT/USD", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp     open     high      low    close        volume
# 0    1597708800000  50.0000  50.7000   2.9000   3.1099  3.415657e+06
# 1    1597795200000   3.1099   3.1600   2.7100   2.9175  1.378930e+06
# 2    1597881600000   2.9175   2.9600   2.7300   2.9090  8.888622e+05
# 3    1597968000000   2.9380   3.7000   2.8000   3.0776  1.066974e+06
# 4    1598054400000   3.0776   4.4866   2.8500   4.4515  4.022332e+06
# ..             ...      ...      ...      ...      ...           ...
# 307  1624233600000  20.6083  20.7723  15.1791  15.7262  2.679093e+06
# 308  1624320000000  15.7059  16.9426  13.0000  14.6740  3.093355e+06
# 309  1624406400000  14.6777  16.8104  14.3722  15.7988  1.431673e+06
# 310  1624492800000  15.8149  16.7008  14.7439  16.2185  8.856016e+05
# 311  1624579200000  16.2130  16.6082  16.1800  16.5520  2.343862e+04
#
# [312 rows x 6 columns]

# %%
historical_prices = exchange.fetch_ohlcv("ADA/USD", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1562457600000  0.077234  0.080589  0.076736  0.080156  4.183640e+06
# 1    1562544000000  0.080182  0.082424  0.079211  0.080242  8.618033e+06
# 2    1562630400000  0.080500  0.080900  0.077080  0.078143  1.025774e+07
# 3    1562716800000  0.077917  0.078400  0.069313  0.071533  1.581579e+07
# 4    1562803200000  0.071400  0.071618  0.062600  0.064872  1.534136e+07
# ..             ...       ...       ...       ...       ...           ...
# 715  1624233600000  1.427186  1.435508  1.168154  1.174492  4.456845e+07
# 716  1624320000000  1.174225  1.262971  1.000004  1.154341  8.360137e+07
# 717  1624406400000  1.151403  1.310000  1.125291  1.250003  4.119551e+07
# 718  1624492800000  1.250100  1.399000  1.200981  1.358665  2.897555e+07
# 719  1624579200000  1.359844  1.387254  1.359558  1.378774  8.568164e+05
#
# [720 rows x 6 columns]

# %%
historical_prices = exchange.fetch_ohlcv("DOGE/USD", "1d")
# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1576713600000  0.002100  0.037000  0.002100  0.002500  1.665000e+04
# 1    1576800000000  0.002052  0.002300  0.002000  0.002020  6.796013e+05
# 2    1576886400000  0.002100  0.002100  0.002100  0.002100  7.484094e+05
# 3    1576972800000  0.002070  0.002103  0.001953  0.002085  1.614581e+06
# 4    1577059200000  0.002121  0.002306  0.001997  0.002232  1.616856e+05
# ..             ...       ...       ...       ...       ...           ...
# 550  1624233600000  0.280197  0.281073  0.164877  0.178367  2.625419e+08
# 551  1624320000000  0.178460  0.217059  0.163000  0.190553  3.192104e+08
# 552  1624406400000  0.190600  0.250624  0.184458  0.234550  2.218432e+08
# 553  1624492800000  0.234942  0.269796  0.221956  0.263504  1.307166e+08
# 554  1624579200000  0.263760  0.267937  0.263760  0.265639  1.054730e+06
#
# [555 rows x 6 columns]

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp          open          high           low         close  \
# 0  1562457600000  3.100000e-07  3.200000e-07  3.000000e-07  3.200000e-07
# 1  1562544000000  3.200000e-07  3.200000e-07  2.800000e-07  2.900000e-07
# 2  1562630400000  2.900000e-07  2.900000e-07  2.900000e-07  2.900000e-07
# 3  1562716800000  2.900000e-07  2.900000e-07  2.900000e-07  2.900000e-07
# 4  1562803200000  2.800000e-07  2.900000e-07  2.700000e-07  2.900000e-07
#
#          volume       date
# 0  1.056104e+07 2019-07-07
# 1  3.654226e+07 2019-07-08
# 2  0.000000e+00 2019-07-09
# 3  0.000000e+00 2019-07-10
# 4  1.487432e+07 2019-07-11

# %%
import nltk
