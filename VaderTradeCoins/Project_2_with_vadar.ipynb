# %%
import ccxt
import os
import pandas as pd
from dotenv import load_dotenv
import panel as pn
import numpy as np

# %%
# Load environment variables 
load_dotenv()

# Import environment variables
kraken_public_key = os.getenv("+a6ycjNigyqUOgCFm5OsTN9UBNse3Htdvjj/qBe8QlhACvvMgEoPrzlX")
kraken_secret_key = os.getenv("+a6ycjNigyqUOgCFm5OsTN9UBNse3Htdvjj/qBe8QlhACvvMgEoPrzlX")

# Verify that environment variables were loaded
print(f"Kraken key data type: {type(kraken_public_key)}")
print(f"Kraken secren data type: {type(kraken_secret_key)}")
# Out:
# Kraken key data type: <class 'NoneType'>
# Kraken secren data type: <class 'NoneType'>

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()
#timePeriod = 180
# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)
#timePeriod = 180
# Display sample data
crypto_df
# Out:
#                                                      AAVE/AUD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.02, 'max': 100000000.0}, ...
# id                                                    AAVEAUD
# symbol                                               AAVE/AUD
# base                                                     AAVE
# quote                                                     AUD
# baseId                                                   AAVE
# quoteId                                                  ZAUD
# darkpool                                                False
# ...

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['AAVE/AUD' 'AAVE/ETH' 'AAVE/EUR' 'AAVE/GBP' 'AAVE/USD' 'AAVE/BTC'
#  'ADA/AUD' 'ADA/ETH' 'ADA/EUR' 'ADA/GBP' 'ADA/USD' 'ADA/USDT' 'ADA/BTC'
#  'ALGO/ETH' 'ALGO/EUR' 'ALGO/GBP' 'ALGO/USD' 'ALGO/BTC' 'ANKR/EUR'
#  'ANKR/GBP' 'ANKR/USD' 'ANKR/BTC' 'ANT/ETH' 'ANT/EUR' 'ANT/USD' 'ANT/BTC'
#  'ATOM/AUD' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/GBP' 'ATOM/USD' 'ATOM/BTC'
#  'AUD/JPY' 'AUD/USD' 'BAL/ETH' 'BAL/EUR' 'BAL/USD' 'BAL/BTC' 'BAT/ETH'
#  'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH' 'BCH/EUR' 'BCH/GBP'
#  'BCH/JPY' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'BNT/EUR' 'BNT/GBP' 'BNT/USD'
#  'BNT/BTC' 'COMP/ETH' 'COMP/EUR' 'COMP/USD' 'COMP/BTC' 'CRV/ETH' 'CRV/EUR'
#  'CRV/USD' 'CRV/BTC' 'DAI/EUR' 'DAI/USD' 'DAI/USDT' 'DASH/EUR' 'DASH/USD'
#  'DASH/BTC' 'DOT/AUD' 'DOT/ETH' 'DOT/EUR' 'DOT/GBP' 'DOT/USD' 'DOT/USDT'
#  'DOT/BTC' 'ENJ/EUR' 'ENJ/GBP' 'ENJ/USD' 'ENJ/BTC' 'EOS/ETH' 'EOS/EUR'
#  'EOS/USD' 'EOS/USDT' 'EOS/BTC' 'ETH2.S/ETH' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI'
# ...

# %%
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': True,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
# ...

# %%
#KA = kraken_public_key()
#timePeriod = 180
#
#data = {}
#coin_list = ['filecoin', 'chainlink','litecoin', 'polkadot', 'tezos', 'thorchain', 'nexo', 'parsiq', 'dfohub']
#for coin in gecko_list:
#    try:
#        nested_lists = cg.get_coin_market_chart_by_id(
#            id=coin, vs_currency="usd", days=timePeriod
#        )["prices"]
#        data[coin] = {}
#        data[coin]["timestamps"], data[coin]["values"] = zip(*nested_lists)
#
#    except Exception as e:
#        print(e)
#        print("coin: " + coin)
#
#frame_list = [
#    pd.DataFrame(data[coin]["values"], index=data[coin]["timestamps"], columns=[coin])
#    for coin in gecko_list
#    if coin in data
#]

# %%
#okex = ccxt.okex()
#candles = okex.fetch_ohlcv('ETH/BTC', '1d', okex.parse8601('2020-12-09T00:00:00'))
#print([okex.iso8601(c[0]) for c in candles])

# %%
# Fetch daily candlestick bar data from `BTC/USD`180 days
ETH_prices = exchange.fetch_ohlcv("ETH/USDC", "1d", okex.parse8601('2020-12-30T00:00:00'))
#historical_prices = exchange.fetch_ohlcv("ETH/USDC", "1d")
# Import the data as a Pandas DataFrame and set the columns
ETH_prices_df = pd.DataFrame(
    ETH_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
ETH_prices_df
# Out:
#          timestamp     open     high      low    close       volume
# 0    1609286400000   732.00   771.34   718.15   752.79   922.573832
# 1    1609372800000   752.80   754.82   725.08   738.20   731.696051
# 2    1609459200000   739.09   748.87   716.16   731.53   761.589776
# 3    1609545600000   730.88   789.04   717.77   776.76  1761.670457
# 4    1609632000000   776.11  1012.78   772.20   978.06  3314.517575
# ..             ...      ...      ...      ...      ...          ...
# 178  1624665600000  1809.34  1848.53  1713.24  1832.21  1444.444636
# 179  1624752000000  1814.23  1981.16  1809.34  1976.13   430.961942
# 180  1624838400000  1986.93  2143.00  1964.53  2082.43  1026.800103
# 181  1624924800000  2085.27  2245.05  2085.27  2163.64   692.695050
# 182  1625011200000  2167.88  2168.75  2145.43  2161.91    24.214095
#
# [183 rows x 6 columns]

# %%
#ETH_prices_df2 = pd.DataFrame(ETH_prices_df, index_col="timestamp", infer_datetime_format=True, parse_dates=True)

# %%
#ETH_prices_df["datetime"] = pd.to_datetime(ETH_prices_df.index, unit="ms")
#ETH_prices_df["date"] = ETH_prices_df["datetime"].dt.date
#ETH_prices_df["hour"] = ETH_prices_df["datetime"].dt.hour
#ETH_prices_df.head(10)

# %%
# timestamp and look for the dtype, convert in to a datetime format(dtype)
# convert date into mm-dd-yyyy
#new_ETH_prices_df = set_index("timestamp")
#ETH_prices_df = ETH_prices_df.drop(["datetime", "hour"], axis=1)
#ETH_prices_df.set_index('date', inplace=True)
#ETH_prices_df.head(10)
#ETH_prices_df.info()

# %%
new_ETH_prices_df = ETH_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_ETH_prices_df
# Out:
#          timestamp     open    close
# 0    1609286400000   732.00   752.79
# 1    1609372800000   752.80   738.20
# 2    1609459200000   739.09   731.53
# 3    1609545600000   730.88   776.76
# 4    1609632000000   776.11   978.06
# ..             ...      ...      ...
# 178  1624665600000  1809.34  1832.21
# 179  1624752000000  1814.23  1976.13
# 180  1624838400000  1986.93  2082.43
# 181  1624924800000  2085.27  2163.64
# 182  1625011200000  2167.88  2161.91
#
# [183 rows x 3 columns]

# %%
#new_ETH_prices_df.set_index=("timestamp", inplace = True)
#new_ETH_prices_df.set_index('timestamp', inplace=True)

# %%
ETH_daily_returns = new_ETH_prices_df.pct_change()
ETH_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054  0.028415 -0.019381
# 2     0.000054 -0.018212 -0.009035
# 3     0.000054 -0.011108  0.061829
# 4     0.000054  0.061884  0.259153
# ..         ...       ...       ...
# 178   0.000053 -0.090551  0.007927
# 179   0.000053  0.002703  0.078550
# 180   0.000053  0.095192  0.053792
# 181   0.000053  0.049493  0.038998
# 182   0.000053  0.039616 -0.000800
#
# [183 rows x 3 columns]

# %%
#ETH_daily_returns.plot()
ETH_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Ethereum", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
#ETH_prices = pd.concat(DataFrame, axis=1).sort_index()
#ETH_prices.head (30)

# %%
volatility = daily_returns.std() * np.sqrt(252)
volatility.sort_values(inplace=True)
volatility
# Out:
# timestamp    0.000002
# close        1.074660
# open         1.081044
# dtype: float64

# %%
#sharpe ratio graph for sentiment

# %%
BTC_prices = exchange.fetch_ohlcv("BTC/USDC", "1d", okex.parse8601('2020-12-30T00:00:00'))
# Import the data as a Pandas DataFrame and set the columns
BTC_prices_df = pd.DataFrame(
    BTC_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
BTC_prices_df
# Out:
#          timestamp      open      high       low     close      volume
# 0    1609286400000  27380.25  29014.20  27380.25  28776.44   78.206310
# 1    1609372800000  28919.70  29276.14  27772.20  29027.83   78.748086
# 2    1609459200000  29047.06  29695.43  28673.20  29360.10   45.704417
# 3    1609545600000  29411.38  33248.00  29058.59  32199.54  197.468157
# 4    1609632000000  32200.00  35070.46  32063.64  32788.25  132.741930
# ..             ...       ...       ...       ...       ...         ...
# 178  1624665600000  31609.56  32675.77  30195.00  32263.94  174.910555
# 179  1624752000000  32220.92  34697.00  32097.03  34680.64  122.455420
# 180  1624838400000  34706.97  35253.43  33956.72  34454.47   84.718315
# 181  1624924800000  34475.27  36581.06  34262.39  35868.48  119.944069
# 182  1625011200000  35885.47  35913.83  35730.34  35881.05    5.266613
#
# [183 rows x 6 columns]

# %%
new_BTC_prices_df = BTC_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_BTC_prices_df
# Out:
#          timestamp      open     close
# 0    1609286400000  27380.25  28776.44
# 1    1609372800000  28919.70  29027.83
# 2    1609459200000  29047.06  29360.10
# 3    1609545600000  29411.38  32199.54
# 4    1609632000000  32200.00  32788.25
# ..             ...       ...       ...
# 178  1624665600000  31609.56  32263.94
# 179  1624752000000  32220.92  34680.64
# 180  1624838400000  34706.97  34454.47
# 181  1624924800000  34475.27  35868.48
# 182  1625011200000  35885.47  35881.05
#
# [183 rows x 3 columns]

# %%
new_BTC_daily_returns = new_BTC_prices_df.pct_change()
new_BTC_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054  0.056225  0.008736
# 2     0.000054  0.004404  0.011447
# 3     0.000054  0.012542  0.096711
# 4     0.000054  0.094814  0.018283
# ..         ...       ...       ...
# 178   0.000053 -0.088504  0.016782
# 179   0.000053  0.019341  0.074904
# 180   0.000053  0.077156 -0.006522
# 181   0.000053 -0.006676  0.041040
# 182   0.000053  0.040905  0.000350
#
# [183 rows x 3 columns]

# %%
new_BTC_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Altcoins", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
#BTC_prices_df.drop(2-3: 5)

# %%
LINK_prices = exchange.fetch_ohlcv("LINK/USD", "1d", okex.parse8601('2020-12-30T00:00:00'))
# Import the data as a Pandas DataFrame and set the columns
LINK_prices_df = pd.DataFrame(
    LINK_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
LINK_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1609286400000  11.77010  11.95840  11.07674  11.25973  5.728227e+05
# 1    1609372800000  11.26205  11.76106  10.95001  11.25169  5.338786e+05
# 2    1609459200000  11.25000  12.48555  11.07800  11.87019  5.454669e+05
# 3    1609545600000  11.87258  12.41780  11.50000  12.20905  5.972783e+05
# 4    1609632000000  12.21602  14.02523  11.85960  13.69552  1.302937e+06
# ..             ...       ...       ...       ...       ...           ...
# 178  1624665600000  16.88430  17.51699  15.94535  16.95176  3.120541e+05
# 179  1624752000000  16.94668  18.40353  16.61102  18.39704  2.857288e+05
# 180  1624838400000  18.40922  19.42099  17.92921  18.80914  3.089270e+05
# 181  1624924800000  18.81274  20.53908  18.76587  19.51896  4.590638e+05
# 182  1625011200000  19.52367  19.54078  19.16700  19.45119  9.906767e+03
#
# [183 rows x 6 columns]

# %%
new_LINK_prices_df = LINK_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_LINK_prices_df
# Out:
#          timestamp      open     close
# 0    1609286400000  11.77010  11.25973
# 1    1609372800000  11.26205  11.25169
# 2    1609459200000  11.25000  11.87019
# 3    1609545600000  11.87258  12.20905
# 4    1609632000000  12.21602  13.69552
# ..             ...       ...       ...
# 178  1624665600000  16.88430  16.95176
# 179  1624752000000  16.94668  18.39704
# 180  1624838400000  18.40922  18.80914
# 181  1624924800000  18.81274  19.51896
# 182  1625011200000  19.52367  19.45119
#
# [183 rows x 3 columns]

# %%
new_LINK_daily_returns = new_LINK_prices_df.pct_change()
new_LINK_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054 -0.043164 -0.000714
# 2     0.000054 -0.001070  0.054970
# 3     0.000054  0.055340  0.028547
# 4     0.000054  0.028927  0.121751
# ..         ...       ...       ...
# 178   0.000053 -0.112975  0.002116
# 179   0.000053  0.003695  0.085258
# 180   0.000053  0.086302  0.022400
# 181   0.000053  0.021919  0.037738
# 182   0.000053  0.037790 -0.003472
#
# [183 rows x 3 columns]

# %%
new_LINK_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Altcoins", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
DOT_prices = exchange.fetch_ohlcv("DOT/USD", "1d", okex.parse8601('2020-12-30T00:00:00'))
# Import the data as a Pandas DataFrame and set the columns
DOT_prices_df = pd.DataFrame(
    DOT_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
DOT_prices_df
# Out:
#          timestamp     open     high      low    close        volume
# 0    1609286400000   7.5462   7.6528   7.0501   7.2320  1.616362e+06
# 1    1609372800000   7.2318   9.5346   7.1520   9.2787  3.180339e+06
# 2    1609459200000   9.2727   9.4357   8.1010   8.3007  2.056748e+06
# 3    1609545600000   8.3000   9.8400   7.9202   9.2198  3.194434e+06
# 4    1609632000000   9.2145  10.5000   8.8504  10.1587  2.859155e+06
# ..             ...      ...      ...      ...      ...           ...
# 178  1624665600000  14.4133  14.9634  13.6325  14.5219  7.248493e+05
# 179  1624752000000  14.5010  15.0159  14.0544  14.9984  7.788065e+05
# 180  1624838400000  15.0159  16.0206  14.6112  15.7705  7.278636e+05
# 181  1624924800000  15.7704  17.0702  15.7580  16.2623  9.955815e+05
# 182  1625011200000  16.2886  16.3313  16.0325  16.2318  1.638871e+04
#
# [183 rows x 6 columns]

# %%
new_DOT_prices_df = DOT_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_DOT_prices_df
# Out:
#          timestamp     open    close
# 0    1609286400000   7.5462   7.2320
# 1    1609372800000   7.2318   9.2787
# 2    1609459200000   9.2727   8.3007
# 3    1609545600000   8.3000   9.2198
# 4    1609632000000   9.2145  10.1587
# ..             ...      ...      ...
# 178  1624665600000  14.4133  14.5219
# 179  1624752000000  14.5010  14.9984
# 180  1624838400000  15.0159  15.7705
# 181  1624924800000  15.7704  16.2623
# 182  1625011200000  16.2886  16.2318
#
# [183 rows x 3 columns]

# %%
new_DOT_daily_returns = new_DOT_prices_df.pct_change()
new_DOT_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054 -0.041663  0.283006
# 2     0.000054  0.282212 -0.105403
# 3     0.000054 -0.104899  0.110726
# 4     0.000054  0.110181  0.101835
# ..         ...       ...       ...
# 178   0.000053 -0.111004  0.006041
# 179   0.000053  0.006085  0.032813
# 180   0.000053  0.035508  0.051479
# 181   0.000053  0.050247  0.031185
# 182   0.000053  0.032859 -0.001876
#
# [183 rows x 3 columns]

# %%
new_DOT_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Altcoins", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
ADA_prices = exchange.fetch_ohlcv("ADA/USD", "1d", okex.parse8601('2020-12-30T00:00:00'))
# Import the data as a Pandas DataFrame and set the columns
ADA_prices_df = pd.DataFrame(
    ADA_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
ADA_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1609286400000  0.190900  0.193312  0.175347  0.183967  4.412935e+07
# 1    1609372800000  0.184008  0.186319  0.175500  0.181689  3.574033e+07
# 2    1609459200000  0.181702  0.184970  0.150000  0.175550  3.765969e+07
# 3    1609545600000  0.175445  0.184740  0.168805  0.177523  4.678945e+07
# 4    1609632000000  0.177498  0.210000  0.173146  0.206796  6.079318e+07
# ..             ...       ...       ...       ...       ...           ...
# 178  1624665600000  1.252974  1.290689  1.198611  1.251661  1.806904e+07
# 179  1624752000000  1.251493  1.348425  1.242130  1.336381  1.243026e+07
# 180  1624838400000  1.337807  1.349186  1.305474  1.326000  1.483414e+07
# 181  1624924800000  1.326218  1.420000  1.320658  1.371268  1.781157e+07
# 182  1625011200000  1.372703  1.372703  1.355000  1.368815  3.427187e+05
#
# [183 rows x 6 columns]

# %%
new_ADA_prices_df = ADA_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_ADA_prices_df
# Out:
#          timestamp      open     close
# 0    1609286400000  0.190900  0.183967
# 1    1609372800000  0.184008  0.181689
# 2    1609459200000  0.181702  0.175550
# 3    1609545600000  0.175445  0.177523
# 4    1609632000000  0.177498  0.206796
# ..             ...       ...       ...
# 178  1624665600000  1.252974  1.251661
# 179  1624752000000  1.251493  1.336381
# 180  1624838400000  1.337807  1.326000
# 181  1624924800000  1.326218  1.371268
# 182  1625011200000  1.372703  1.368815
#
# [183 rows x 3 columns]

# %%
new_ADA_daily_returns = new_ADA_prices_df.pct_change()
new_ADA_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054 -0.036103 -0.012383
# 2     0.000054 -0.012532 -0.033789
# 3     0.000054 -0.034436  0.011239
# 4     0.000054  0.011702  0.164897
# ..         ...       ...       ...
# 178   0.000053 -0.078590 -0.002428
# 179   0.000053 -0.001182  0.067686
# 180   0.000053  0.068969 -0.007768
# 181   0.000053 -0.008663  0.034139
# 182   0.000053  0.035051 -0.001789
#
# [183 rows x 3 columns]

# %%
new_ADA_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Altcoins", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
DOGE_prices = exchange.fetch_ohlcv("DOGE/USD", "1d", okex.parse8601('2020-12-30T00:00:00'))
# Import the data as a Pandas DataFrame and set the columns
DOGE_prices_df = pd.DataFrame(
    DOGE_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
DOGE_prices_df
# Out:
#          timestamp      open      high       low     close        volume
# 0    1609286400000  0.004481  0.004700  0.004420  0.004621  7.696812e+07
# 1    1609372800000  0.004660  0.004740  0.004519  0.004684  6.043130e+07
# 2    1609459200000  0.004680  0.005761  0.004604  0.005708  2.426560e+08
# 3    1609545600000  0.005776  0.014282  0.005579  0.010578  2.188066e+09
# 4    1609632000000  0.010504  0.013889  0.009132  0.009846  1.208614e+09
# ..             ...       ...       ...       ...       ...           ...
# 178  1624665600000  0.237934  0.255088  0.231000  0.245759  9.544349e+07
# 179  1624752000000  0.245759  0.267548  0.240428  0.265000  5.676430e+07
# 180  1624838400000  0.265000  0.267135  0.250834  0.257081  4.172702e+07
# 181  1624924800000  0.257081  0.275720  0.252510  0.263287  5.859184e+07
# 182  1625011200000  0.263044  0.263622  0.257076  0.260015  2.498597e+06
#
# [183 rows x 6 columns]

# %%
new_DOGE_prices_df = DOGE_prices_df.drop(columns = ['volume', 'high', 'low', ])
new_DOGE_prices_df
# Out:
#          timestamp      open     close
# 0    1609286400000  0.004481  0.004621
# 1    1609372800000  0.004660  0.004684
# 2    1609459200000  0.004680  0.005708
# 3    1609545600000  0.005776  0.010578
# 4    1609632000000  0.010504  0.009846
# ..             ...       ...       ...
# 178  1624665600000  0.237934  0.245759
# 179  1624752000000  0.245759  0.265000
# 180  1624838400000  0.265000  0.257081
# 181  1624924800000  0.257081  0.263287
# 182  1625011200000  0.263044  0.260015
#
# [183 rows x 3 columns]

# %%
new_DOGE_daily_returns = new_DOGE_prices_df.pct_change()
new_DOGE_daily_returns
# Out:
#      timestamp      open     close
# 0          NaN       NaN       NaN
# 1     0.000054  0.040060  0.013589
# 2     0.000054  0.004313  0.218517
# 3     0.000054  0.234083  0.853151
# 4     0.000054  0.818508 -0.069146
# ..         ...       ...       ...
# 178   0.000053 -0.097913  0.034043
# 179   0.000053  0.032886  0.078291
# 180   0.000053  0.078291 -0.029884
# 181   0.000053 -0.029883  0.024140
# 182   0.000053  0.023195 -0.012426
#
# [183 rows x 3 columns]

# %%
new_DOGE_daily_returns.hvplot.line(xlabel="timestamp", ylabel="Daily % change", title= "Daily Return of Altcoins", height=450, width=800)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
pip install hvplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import hvplot.pandas

# %%
import panel as pn
import numpy as np

# %%
matrix = np.triu(corr)
corr = historical_prices_df.dropna().corr()
plt.figure(figsize=(15,6))
sns.heatmap(corr,
            xticklabels=corr.columns,
            yticklabels=corr.columns, 
            annot=True,
            cmap='Blues',mask=matrix)
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-444-3cd22121af4c> in <module>
# ----> 1 matrix = np.triu(corr)
#       2 corr = historical_prices_df.dropna().corr()
#       3 plt.figure(figsize=(15,6))
#       4 sns.heatmap(corr,
#       5             xticklabels=corr.columns,
#
# NameError: name 'corr' is not defined

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
px.scatter(historical_prices_df, x="close", y="open",color="open")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-447-2b2fec8edfe8> in <module>
# ----> 1 px.scatter(historical_prices_df, x="close", y="open",color="open")
#
# NameError: name 'historical_prices_df' is not defined

# %%
historical_prices_df.plot(kind='scatter', x='close', y='pct_change')

# %%
import seaborn as sns

# %%
sns.heatmap(historical_prices_df, vmin=-1, vmax=1)

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()

# %%
historical_prices_df.plot('open', 'high', 'low', 'volume', 'timestamp')

# %%
import nltk

# %%
pip install tweepy

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
#import twitter_credentials

# %%
twitter api = "HpxdPCgOF7Acz68cCg3OVPXSo"
secret key = "RQRMiDAxhZ82SRrgFaXQO5Zv2GjAcyhd3Y2hoPRaI1eSNaopr3"
bearer key = "AAAAAAAAAAAAAAAAAAAAAAVrRAEAAAAA1z9JqWk0DiTr2zXM5%2FLzMmJqPNs%3D78JUdaX6prtnnSlrK4HH7jnIczqh7W6hj0ZwO61rzzGrTVrfWa"
Access Token Secret = "tgqvVKrNczQr1SzyB4p9LITM7eP5Y948k0RyxdpfwGEtV"
Access Token = "1266195535805009923-q1z4hZA45El88o3bKE971nnqDF0Kkg"

# %%
class StdOutListener(StreamListener):
    def on data(self, data):
        print(data)
        return True
    def on error(self, status):
        print(status)
        
if _name__ == "__main__":
    listener = StdOutListener()
    auth = OAuthHandler(twitter credentials.CONSUMER KEY, twitter credentials.CONSUMER SECRET)
    auth.set access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
    stream = Stream(auth, listener)

# %%
{
    "id": "11215300-7cf8-40d8-81ec-e70830270adc",
    "name": "Twitter API v2",
    "values": [
        {
            "key": "consumer_key",
            "value": "Your consumer key",
            "enabled": true
        },
        {
            "key": "consumer_secret",
			"value": "Your consumer secret",
			"enabled": true
		},
		{
			"key": "access_token",
			"value": "Your access token",
			"enabled": true
		},
		{
			"key": "token_secret",
			"value": "Your token secret",
			"enabled": true
		},
		{
			"key": "bearer_token",
			"value": null,
			"enabled": true
		}
	],
	"_postman_variable_scope": "environment",
	"_postman_exported_at": "2020-12-17T21:46:42.263Z",
	"_postman_exported_using": "Postman/7.36.1"
}

# %%
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/ldb/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd
import numpy as np

import pandas_datareader as pdr
import matplotlib.pyplot as plt

data_btc = pdr.get_data_yahoo('ETH', '24-Feb-20') 
data_btc.head()
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2020-02-24  14.50  13.95  14.23  14.23  364300.0  13.012279
# 2020-02-25  14.23  13.20  14.23  13.37  276900.0  12.225873
# 2020-02-26  13.71  13.22  13.40  13.45  306800.0  12.299027
# 2020-02-27  13.66  13.09  13.16  13.35  429600.0  12.207584
# 2020-02-28  13.41  13.00  13.03  13.20  376100.0  12.070421

# %%
import requests 
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'

# Specify the query and number of returns
parameters = {
    'q': 'ETH', # query phrase
    'sortBy': 'popularity', # articles from popular sources and publishers come first
    'pageSize': 100,  # maximum is 100 for developer version
    'apiKey': '6328236de8a042eba8425dcef7ff96dc', # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and store it in dataframe
data = pd.DataFrame(response.json())

news_df = pd.concat([data['articles'].apply(pd.Series)], axis=1)

final_news = news_df.loc[:,['publishedAt','title']]
final_news['publishedAt'] = pd.to_datetime(final_news['publishedAt'])
final_news.sort_values(by='publishedAt',inplace=True)

# Import BDay to determine business day's dates
from pandas.tseries.offsets import BDay

# to get the business day for which particular news headline should be used to make trade calls
def get_trade_open(date):
    curr_date_open = pd.to_datetime(date).floor('d').replace(hour=13,minute=30) - BDay(0)
    curr_date_close = pd.to_datetime(date).floor('d').replace(hour=20,minute=0) - BDay(0)
    
    prev_date_close = (curr_date_open - BDay()).replace(hour=20,minute=0)
    next_date_open = (curr_date_close + BDay()).replace(hour=13,minute=30)
    
    if ((pd.to_datetime(date)>=prev_date_close) & (pd.to_datetime(date)<curr_date_open)):
        return curr_date_open
    elif ((pd.to_datetime(date)>=curr_date_close) & (pd.to_datetime(date)<next_date_open)):
        return next_date_open
    else:
        return None
      
 # Apply the above function to get the trading time for each news headline
final_news["trading_time"] = final_news["publishedAt"].apply(get_trade_open)

final_news = final_news[pd.notnull(final_news['trading_time'])]
final_news['Date'] = pd.to_datetime(pd.to_datetime(final_news['trading_time']).dt.date)

# %%
cs = []
for row in range(len(final_news)):
    cs.append(analyzer.polarity_scores(final_news['title'].iloc[row])['compound'])

final_news['compound_vader_score'] = cs
final_news = final_news[(final_news[['compound_vader_score']] != 0).all(axis=1)].reset_index(drop=True)

final_news.head()
# Out:
#                 publishedAt  \
# 0 2021-05-29 12:45:00+00:00
# 1 2021-05-31 05:14:53+00:00
# 2 2021-06-03 02:58:35+00:00
# 3 2021-06-03 06:51:13+00:00
# 4 2021-06-04 00:17:00+00:00
#
#                                                title  \
# 0  Investors Who Worry About Bitcoin Should Remem...
# 1  Top Cryptocurrency Prices Today: Cardano, Ethe...
# 2  Experimental vaccine forces bacteria down an e...
# 3  Antivirus that mines Ethereum sounds a bit wro...
# 4  Why Cryptocurrency Investors Are Excited About...
#
#                trading_time       Date  compound_vader_score
# 0 2021-05-31 13:30:00+00:00 2021-05-31               -0.4404
# 1 2021-05-31 13:30:00+00:00 2021-05-31                0.6369
# 2 2021-06-03 13:30:00+00:00 2021-06-03               -0.6486
# 3 2021-06-03 13:30:00+00:00 2021-06-03               -0.4767
# 4 2021-06-04 13:30:00+00:00 2021-06-04                0.3400

# %%
unique_dates = final_news['Date'].unique()
grouped_dates = final_news.groupby(['Date'])
keys_dates = list(grouped_dates.groups.keys())

max_cs = []
min_cs = []

for key in grouped_dates.groups.keys():
    data = grouped_dates.get_group(key)
    if data["compound_vader_score"].max() > 0:
        max_cs.append(data["compound_vader_score"].max())
    elif data["compound_vader_score"].max() < 0:
        max_cs.append(0)
    
    if data["compound_vader_score"].min() < 0:
        min_cs.append(data["compound_vader_score"].min())
    elif data["compound_vader_score"].min() > 0:
        min_cs.append(0)
    
extreme_scores_dict = {'Date':keys_dates,'max_scores':max_cs,'min_scores':min_cs}
extreme_scores_df = pd.DataFrame(extreme_scores_dict)

# %%
final_scores = []
for i in range(len(extreme_scores_df)):
    final_scores.append(extreme_scores_df['max_scores'].values[i] + extreme_scores_df['min_scores'].values[i])

extreme_scores_df['final_scores'] = final_scores

extreme_scores_df.head()
# Out:
#         Date  max_scores  min_scores  final_scores
# 0 2021-05-31      0.6369     -0.4404        0.1965
# 1 2021-06-03      0.0000     -0.6486       -0.6486
# 2 2021-06-04      0.3400      0.0000        0.3400
# 3 2021-06-07      0.3182     -0.2263        0.0919
# 4 2021-06-08      0.2500      0.0000        0.2500

# %%
# VADER trade calls - with threshold
vader_Buy=[]
vader_Sell=[]
for i in range(len(extreme_scores_df)):
    if extreme_scores_df['final_scores'].values[i] > 0.20:
        print("Trade Call for {row} is Buy.".format(row=extreme_scores_df['Date'].iloc[i].date()))
        vader_Buy.append(extreme_scores_df['Date'].iloc[i].date())
    elif extreme_scores_df['final_scores'].values[i] < -0.20:
        print("Trade Call for {row} is Sell.".format(row=extreme_scores_df['Date'].iloc[i].date()))
        vader_Sell.append(extreme_scores_df['Date'].iloc[i].date())
# Out:
# Trade Call for 2021-06-03 is Sell.
# Trade Call for 2021-06-04 is Buy.
# Trade Call for 2021-06-08 is Buy.
# Trade Call for 2021-06-15 is Buy.
# Trade Call for 2021-06-16 is Buy.
# Trade Call for 2021-06-22 is Buy.
# Trade Call for 2021-06-24 is Sell.
# Trade Call for 2021-06-28 is Buy.

# %%
vader_buy = []
for i in range(len(ETH_prices_df)):
    if ETH_prices_df.index[i] in vader_Buy:
        vader_buy.append(i)
        
vader_sell = []
for i in range(len(ETH_prices_df)):
    if ETH_prices_df.index[i] in vader_Sell:
        vader_sell.append(i)
        
plt.figure(figsize=(20, 10),dpi=80)
plt.plot(ETH_prices_df.index, ETH_prices_df['close'],'-^', markevery=vader_buy, ms=15, color='green')
plt.plot(ETH_prices_df.index, ETH_prices_df['close'],'-v', markevery=vader_sell, ms=15, color='red')
plt.plot(ETH_prices_df.index, ETH_prices_df['close'])
plt.xlabel('Date',fontsize=14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(rotation='60',fontsize=12)
plt.yticks(fontsize=12)
plt.title('Trade Calls - VADER', fontsize = 16)
plt.legend(['Buy','Sell','close'])
plt.grid()
plt.show()

# %%
ETH_prices_df['2_SMA'] = ETH_prices_df['close'].rolling(window=2).mean()
ETH_prices_df['5_SMA'] = ETH_prices_df['close'].rolling(window=5).mean()

ETH_prices_df = ETH_prices_df[ETH_prices_df['5_SMA'].notna()]

# SMA trade calls
Trade_Buy=[]
Trade_Sell=[]
for i in range(len(ETH_prices_df)-1):
    if ((ETH_prices_df['2_SMA'].values[i] < ETH_prices_df['5_SMA'].values[i]) & (ETH_prices_df['2_SMA'].values[i+1] > ETH_prices_df['5_SMA'].values[i+1])):
        #print("Trade Call for {row} is Buy.".format(row=data_amd.index[i].date()))
        print("Hit the if")
        #Trade_Buy.append(i)
    elif ((ETH_prices_df['2_SMA'].values[i] > ETH_prices_df['5_SMA'].values[i]) & (ETH_prices_df['2_SMA'].values[i+1] < ETH_prices_df['5_SMA'].values[i+1])):
        #print("Trade Call for {row} is Sell.".format(row=ETH_prices_df.index[i].date()))
        print("Hit the elif")
        #Trade_Sell.append(i)
# Out:
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# Hit the elif
# Hit the if
# /Users/ldb/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ...

# %%
plt.figure(figsize=(20, 10),dpi=80)
plt.plot(ETH_prices_df.index, ETH_prices_df['close'])
plt.plot(ETH_prices_df.index, ETH_prices_df['2_SMA'],'-^', markevery=Trade_Buy, ms=15, color='green')
plt.plot(ETH_prices_df.index, ETH_prices_df['5_SMA'],'-v', markevery=Trade_Sell, ms=15, color='red')
plt.xlabel('Date',fontsize=14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(rotation='60',fontsize=12)
plt.yticks(fontsize=12)
plt.title('Trade Calls - Moving Averages Crossover', fontsize = 16)
plt.legend(['Close','2_SMA','5_SMA'])
plt.grid()
plt.show()

# %%
#prioritising SMA signals
final_buy = list(set(Trade_Buy + vader_buy) - set(Trade_Sell)) 
final_sell = list(set(Trade_Sell + vader_sell) - set(Trade_Buy))

plt.figure(figsize=(20, 10),dpi=80)
plt.plot(ETH_prices_df.index, ETH_prices_df['2_SMA'], color='blue')
plt.plot(ETH_prices_df.index, ETH_prices_df['5_SMA'], color='orange')
plt.plot(ETH_prices_df.index, ETH_prices_df['close'],'-^', markevery=final_buy, ms=15, color='green')
plt.plot(ETH_prices_df.index, ETH_prices_df['close'],'-v', markevery=final_sell, ms=15, color='red')
plt.plot(ETH_prices_df.index, ETH_prices_df['close'])
plt.xlabel('Date',fontsize=14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(rotation='60',fontsize=12)
plt.yticks(fontsize=12)
plt.title('Trade Calls - MERGED', fontsize = 16)
plt.legend(['2_SMA','5_SMA','Buy','Sell','Close'])
plt.grid()
plt.show()
